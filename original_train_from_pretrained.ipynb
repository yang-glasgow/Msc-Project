# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import librosa
import torchaudio
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys

from tqdm.auto import tqdm
from IPython.display import Audio

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA version: {torch.version.cuda}")
print(f"CUDNN version: {torch.backends.cudnn.version()}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# cuda
# PyTorch version: 2.3.1
# CUDA version: 12.1
# CUDNN version: 8907
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
file_path = './TIMIT/'
data_path = './TIMIT/data'

train_data = pd.read_csv(os.path.join(file_path, 'train_data.csv'))
test_data = pd.read_csv(os.path.join(file_path, 'test_data.csv'))
df = pd.concat([train_data, test_data])

# %%
audio_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str:
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in audio_files:
            audio_files[filename]={}
        
        if filename in audio_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                audio_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                audio_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                audio_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(audio_files))
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break
# Out:
# 6300
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}

# %%
female_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str and row['speaker_id'].startswith('F'):
        if filename.split('.')[0] in ['SA1','SA2']:
            continue
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in female_files:
            female_files[filename]={}
        
        if filename in female_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                female_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                female_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                female_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(female_files))
# Out:
# 1536

# %%
tacotron_file_list = []
for key,files in female_files.items():
    if len(files) == 3:
        tacotron_file_list.append(files)
print(len(tacotron_file_list))
# Out:
# 792

# %%
# TimitBet 61 phoneme mapping to 39 phonemes
# by Lee, K.-F., & Hon, H.-W. (1989). Speaker-independent phone recognition using hidden Markov models. IEEE Transactions on Acoustics, Speech, and Signal Processing, 37(11), 1641–1648. doi:10.1109/29.46546 
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

# %%
from scipy.io.wavfile import read
y1, sr1 = librosa.load('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav', sr=16000)
sr2, y2 = read('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav')
print(f'Shape of audio sequence: {y2.shape}')
print(f'sample rate: {sr2}')
if np.array_equal(y1, y2):
    print('y1=y2')
else:
    print('y1!=y2')
# Out:
# 音频时间序列的形状: (53556,)
# 采样率: 16000
# y1!=y2

# %%
# def compute_mel_spectrogram(y, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
#     mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
#     log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
#     return log_mel_spectrogram

# %%
# mel_y1 = compute_mel_spectrogram(y1[0:1000])
# print(mel_y1[0])

# %%
# !git clone https://github.com/NVIDIA/DeepLearningExamples.git

# %%
# set the path of model
waveglow_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/'
sys.path.append(waveglow_path)
tacotron2_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/'
sys.path.append(tacotron2_path)

# %%
from denoiser import Denoiser
from model import WaveGlow
import data_function
import loss_function
from loss_function import WaveGlowLoss
import importlib.util
entrypoints_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/entrypoints.py'

spec = importlib.util.spec_from_file_location("entrypoints", entrypoints_path)
entrypoints = importlib.util.module_from_spec(spec)
sys.modules["entrypoints"] = entrypoints
spec.loader.exec_module(entrypoints)

from entrypoints import nvidia_waveglow

# %%
from scipy.io.wavfile import read
import tacotron2_common.layers as layers
max_wav_value = 32768.0

def compute_mel_spectrogram(audio_data, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
    stft = layers.TacotronSTFT(sampling_rate=16000)
    
    audio_norm = audio_data / max_wav_value
    audio_norm = audio_norm.unsqueeze(0)
    audio_norm = torch.autograd.Variable(audio_norm, requires_grad=False)
    melspec = stft.mel_spectrogram(audio_norm)
    melspec = torch.squeeze(melspec, 0)

    return melspec

def load_audio_from_path(path):
    sampling_rate, data = read(path)
    audio_data = torch.FloatTensor(data.astype(np.float32))

    return audio_data

def compute_mel_from_path(path):
    return compute_mel_spectrogram(load_audio_from_path(path))

# %%
from torch.utils.data import DataLoader

def load_mel_audio(file_path, sr=16000, n_mels=80, n_fft=1024, hop_length=256):
    audio = load_audio_from_path(file_path)
    
    melspec = compute_mel_spectrogram(audio)
    
    return melspec, audio

class MelDataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        mel_spectrogram, audio = load_mel_audio(file_path)
        return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)

file_list = []
for (key,value) in female_files.items():
    file_list.append(value['audio_file'])

dataset = MelDataset(file_list)
train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
dataset[0]
# Out:
# C:\Users\YANG\AppData\Local\Temp\ipykernel_17688\556344903.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)
# (tensor([[ -8.4898,  -8.4369,  -9.0065,  ...,  -6.8391,  -7.0954,  -7.3317],
#          [ -9.8049,  -9.1275,  -9.2912,  ...,  -6.9650,  -6.6273,  -6.6464],
#          [ -9.1401,  -9.1792,  -9.6098,  ...,  -7.8798,  -6.9461,  -6.9621],
#          ...,
#          [ -9.7159, -10.0164, -10.0679,  ...,  -9.3277,  -9.2204,  -9.2737],
#          [ -9.5567,  -9.7603,  -9.9210,  ...,  -9.1527,  -9.1147,  -9.2802],
#          [ -9.4876,  -9.6483,  -9.7763,  ...,  -9.7336,  -9.6742,  -9.6836]],
#         device='cuda:0'),
#  tensor([14., -7., -1.,  ..., -4., -4., -1.], device='cuda:0'))

# %%
n_mel_channels = 80
n_flows = 12
n_group = 8
n_early_every = 4
n_early_size = 2
WN_config = {
    "n_layers": 8,
    "n_channels": 512,
    "kernel_size": 3
}

# waveglow = WaveGlow(n_mel_channels, n_flows, n_group, n_early_every, n_early_size, WN_config)
# waveglow = waveglow.cuda()

waveglow =  nvidia_waveglow(pretrained=True, model_math='fp32')
waveglow = waveglow.cuda()
# Out:
# E:\study_software\anaconda\conda\lib\site-packages\torch\nn\utils\weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
from denoiser import Denoiser
tem_mal = compute_mel_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav').to(device)

with torch.no_grad():
    audio = waveglow.infer(tem_mal.unsqueeze(0).to(device), sigma=0.666)

denoiser = Denoiser(waveglow)
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
audio_numpy = audio_denoised.cpu().numpy()

Audio(audio_numpy, rate=18000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
raw_audio = load_audio_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav')
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# TimitBet 61 phoneme mapping to 39 phonemes
# by Lee, K.-F., & Hon, H.-W. (1989). Speaker-independent phone recognition using hidden Markov models. IEEE Transactions on Acoustics, Speech, and Signal Processing, 37(11), 1641–1648. doi:10.1109/29.46546 
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

def play_mel_audio(mel_spectrogram):
    with torch.no_grad():
        audio = waveglow.infer(mel_spectrogram.unsqueeze(0).to(device), sigma=1)
    
    denoiser = Denoiser(waveglow)
    audio_denoised = denoiser(audio, strength=0.01)[:, 0]
    audio_numpy = audio_denoised.cpu().numpy()

    return Audio(audio_numpy, rate=18000)

# %%
def read_and_convert_phonemes(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    end_time = 0
    
    phoneme_indices = []
    
    for line in lines:
        parts = line.strip().split()
        
        if len(parts) != 3:
            continue
        end_time = parts[1]
        phoneme = parts[2]

        if phoneme in pho61_to_pho39:
            pho39 = pho61_to_pho39[phoneme]
            if pho39 in pho39_to_index:
                index = pho39_to_index[pho39]-1
                phoneme_indices.append(index)
    phoneme_indices.append(39)
    
    return phoneme_indices,end_time

# %%
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break

tacotron_file_list = []
for key,files in female_files.items():
    if len(files) == 3:
        tacotron_file_list.append(files)
print(len(tacotron_file_list))
# Out:
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}
# 792

# %%
class Tacotron2Dataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_paths = self.file_list[idx]
        phone_list, end_time = read_and_convert_phonemes(file_paths['phonetic_file'])
        mel_spectrogram = compute_mel_spectrogram(load_audio_from_path(file_paths['audio_file'][0:int(end_time)]))
        
        phone_tensor = torch.tensor(phone_list, dtype=torch.int).clone().detach()
        mel_tensor = mel_spectrogram.float()
        
        return phone_tensor, mel_tensor, len(phone_list)

# %%
tacotron_dataset = Tacotron2Dataset(tacotron_file_list)
tacotron_dataset[0][1].shape
# Out:
# torch.Size([80, 180])

# %%
from tacotron2.model import Tacotron2
from tacotron2.loss_function import Tacotron2Loss
hparams = {
    'n_mel_channels': 80,
    'n_symbols': 40,
    'symbols_embedding_dim': 512,
    'encoder_kernel_size': 5,
    'encoder_n_convolutions': 3,
    'encoder_embedding_dim': 512,
    'attention_rnn_dim': 1024,
    'attention_dim': 128,
    'attention_location_n_filters': 32,
    'attention_location_kernel_size': 31,
    'n_frames_per_step': 1,
    'decoder_rnn_dim': 1024,
    'prenet_dim': 256,
    'max_decoder_steps': 1000,
    'gate_threshold': 0.5,
    'p_attention_dropout': 0.1,
    'p_decoder_dropout': 0.1,
    'postnet_embedding_dim': 512,
    'postnet_kernel_size': 5,
    'postnet_n_convolutions': 5,
    'decoder_no_early_stopping': False,
    'mask_padding': False
}
from tacotron2.entrypoints import nvidia_tacotron2
model = nvidia_tacotron2(pretrained = True, n_symbols = 40).to(device)

# %%
raw_audio = load_audio_from_path(tacotron_file_list[0]['audio_file'])
print(raw_audio.shape)
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
# torch.Size([45978])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
phoneme_sequence,end_time = read_and_convert_phonemes(tacotron_file_list[0]['phonetic_file'])
print(phoneme_sequence)
length = [len(phoneme_sequence)]
inputs = torch.tensor(phoneme_sequence, dtype=torch.int).unsqueeze(0).to(device)
input_lengths = torch.tensor(length, dtype=torch.int).to(device)
print(inputs.shape)
print(input_lengths)
model.eval()

with torch.no_grad():
    mel_outputs, mel_lengths, alignments = model.infer(inputs, input_lengths)

print("Mel Outputs Postnet:", mel_outputs)
print("Mel Lengths:", mel_lengths)
print("Alignments:", alignments)
print(mel_outputs.shape)
play_audio = play_mel_audio(mel_outputs[0])
play_audio
# Out:
# [38, 17, 38, 31, 29, 13, 2, 23, 38, 31, 17, 28, 25, 29, 38, 22, 0, 28, 30, 22, 2, 21, 25, 15, 38, 2, 23, 17, 38, 14, 1, 29, 38, 10, 6, 23, 6, 38, 39]
# torch.Size([1, 39])
# tensor([39], device='cuda:0', dtype=torch.int32)
# Mel Outputs Postnet: tensor([[[-7.3393, -6.3850, -6.1946,  ..., -8.2900, -7.6656, -5.6523],
#          [-6.8412, -5.8914, -5.3982,  ..., -7.1550, -6.7133, -4.9930],
#          [-6.3269, -5.0562, -4.5559,  ..., -6.1024, -5.8314, -4.4243],
#          ...,
#          [-9.6034, -8.8643, -8.6685,  ..., -9.2768, -8.9770, -7.3082],
#          [-9.5483, -8.6583, -8.4372,  ..., -9.2512, -8.9584, -7.2605],
#          [-9.4489, -8.2461, -7.8340,  ..., -9.2847, -8.9700, -7.2585]]],
#        device='cuda:0')
# Mel Lengths: tensor([604], device='cuda:0', dtype=torch.int32)
# Alignments: tensor([[[9.9829e-01, 1.9121e-04, 1.3708e-05,  ..., 4.8683e-06,
#           1.0971e-07, 9.7671e-07],
#          [4.1270e-01, 1.4494e-01, 2.2291e-01,  ..., 3.5622e-03,
#           4.3740e-04, 3.0014e-05],
#          [3.6334e-01, 2.4652e-01, 2.1225e-01,  ..., 7.8833e-03,
#           8.9485e-05, 8.9391e-05],
#          ...,
#          [4.9231e-03, 4.8488e-03, 1.1595e-04,  ..., 8.5551e-02,
#           2.2598e-02, 1.3890e-03],
#          [4.1583e-03, 2.5403e-03, 1.0510e-04,  ..., 8.1122e-02,
#           6.2820e-02, 2.3562e-02],
#          [1.8410e-03, 1.1331e-03, 5.6701e-05,  ..., 1.0498e-01,
#           4.3167e-02, 3.3111e-01]]], device='cuda:0')
# torch.Size([1, 80, 605])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install inflect

# %%
import data_functions
import time
import loss_functions

# torch.autograd.set_detect_anomaly(True)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

model_name = 'Tacotron2'
criterion = loss_functions.get_loss_function(model_name)
collate_fn = data_functions.get_collate_function(model_name)
train_loader = DataLoader(tacotron_dataset, num_workers=0, shuffle=True, batch_size=64, pin_memory=False, drop_last=False, collate_fn=collate_fn)
batch_to_gpu = data_functions.get_batch_to_gpu(model_name)

epochs = 160
grad_clip_thresh = 1.0

model.train()

for epoch in range(epochs):
    mean_loss = 0
    train_count = 0
    torch.cuda.synchronize()
    epoch_start_time = time.perf_counter()
    for i, batch in enumerate(train_loader):

        train_count += 1
        
#         texts, text_lengths, mels, gate_padded, mel_lengths, max_len = batch
#         texts, text_lengths, mels, gate_padded, mel_lengths = texts.to(device), text_lengths.to(device), mels.to(device), gate_padded.to(device), mel_lengths.to(device)

        torch.cuda.synchronize()
        model.zero_grad()
        x, y, num_items = batch_to_gpu(batch)
        outputs = model(x)
#         mel_outputs, mel_outputs_postnet, gate_outputs, alignments = outputs
#         targets = (mels, gate_padded)
        loss = criterion(outputs, y)
        reduced_loss = loss.item()
        if np.isnan(reduced_loss):
            raise Exception("loss is NaN")
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip_thresh)

        optimizer.step()
        model.zero_grad()
        mean_loss += loss.item()
        if (i) % 10 == 0:
            print(f'Epoch: {epoch+1}, Iteration: {i}, Loss: {loss.item()}')
        torch.cuda.synchronize()
    
    torch.cuda.synchronize()
    epoch_end_time = time.perf_counter()
    epoch_time = epoch_end_time - epoch_start_time
    mean_loss = mean_loss / train_count
    print(f'Epoch {epoch + 1} completed in {epoch_time:.2f} seconds, mean loss: {mean_loss}')
    
    if (epoch + 1) % 10 == 0 or epoch == 0:
        checkpoint_path = os.path.join('./pretrained_check_points/',f'checkpoint_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': mean_loss,
        }, checkpoint_path)
        print(f'Checkpoint saved at {checkpoint_path}')
# Out:
# Epoch: 1, Iteration: 0, Loss: 5.273843288421631
# Epoch: 1, Iteration: 10, Loss: 1.746108055114746
# Epoch 1 completed in 403.28 seconds, mean loss: 5.319531009747432
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_1.pt
# Epoch: 2, Iteration: 0, Loss: 1.8258262872695923
# Epoch: 2, Iteration: 10, Loss: 1.1539173126220703
# Epoch 2 completed in 398.11 seconds, mean loss: 1.3705694308647742
# Epoch: 3, Iteration: 0, Loss: 1.1008813381195068
# Epoch: 3, Iteration: 10, Loss: 1.1006227731704712
# Epoch 3 completed in 413.11 seconds, mean loss: 1.226349569283999
# Epoch: 4, Iteration: 0, Loss: 1.18787682056427
# Epoch: 4, Iteration: 10, Loss: 1.041568398475647
# Epoch 4 completed in 376.70 seconds, mean loss: 1.1464477089735179
# Epoch: 5, Iteration: 0, Loss: 1.0439491271972656
# Epoch: 5, Iteration: 10, Loss: 0.8187901377677917
# Epoch 5 completed in 390.72 seconds, mean loss: 1.0480684041976929
# Epoch: 6, Iteration: 0, Loss: 1.1611138582229614
# Epoch: 6, Iteration: 10, Loss: 0.9446406960487366
# Epoch 6 completed in 395.66 seconds, mean loss: 1.0196571946144104
# Epoch: 7, Iteration: 0, Loss: 0.9211896657943726
# Epoch: 7, Iteration: 10, Loss: 1.126624584197998
# Epoch 7 completed in 379.42 seconds, mean loss: 0.9788314195779654
# Epoch: 8, Iteration: 0, Loss: 0.9288157224655151
# Epoch: 8, Iteration: 10, Loss: 0.8797472715377808
# Epoch 8 completed in 401.85 seconds, mean loss: 0.9238597475565397
# Epoch: 9, Iteration: 0, Loss: 0.8547068238258362
# Epoch: 9, Iteration: 10, Loss: 0.9379758834838867
# Epoch 9 completed in 390.27 seconds, mean loss: 0.9200643988756033
# Epoch: 10, Iteration: 0, Loss: 0.9690711498260498
# Epoch: 10, Iteration: 10, Loss: 0.9248983263969421
# Epoch 10 completed in 399.66 seconds, mean loss: 0.898785792864286
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_10.pt
# Epoch: 11, Iteration: 0, Loss: 0.6987498998641968
# Epoch: 11, Iteration: 10, Loss: 0.8596887588500977
# Epoch 11 completed in 397.22 seconds, mean loss: 0.8866634689844571
# Epoch: 12, Iteration: 0, Loss: 0.9209044575691223
# Epoch: 12, Iteration: 10, Loss: 0.7631082534790039
# Epoch 12 completed in 376.71 seconds, mean loss: 0.852787618453686
# Epoch: 13, Iteration: 0, Loss: 0.7554692625999451
# Epoch: 13, Iteration: 10, Loss: 0.8289483189582825
# Epoch 13 completed in 398.63 seconds, mean loss: 0.824235751078679
# Epoch: 14, Iteration: 0, Loss: 0.8009971976280212
# Epoch: 14, Iteration: 10, Loss: 0.7902677059173584
# Epoch 14 completed in 390.29 seconds, mean loss: 0.818197080722222
# Epoch: 15, Iteration: 0, Loss: 0.8167415261268616
# Epoch: 15, Iteration: 10, Loss: 0.6343778371810913
# Epoch 15 completed in 392.77 seconds, mean loss: 0.7964664101600647
# Epoch: 16, Iteration: 0, Loss: 0.7737334370613098
# Epoch: 16, Iteration: 10, Loss: 0.9240743517875671
# Epoch 16 completed in 389.58 seconds, mean loss: 0.8097342619529138
# Epoch: 17, Iteration: 0, Loss: 0.6481021046638489
# Epoch: 17, Iteration: 10, Loss: 0.8469118475914001
# Epoch 17 completed in 404.84 seconds, mean loss: 0.7921823905064509
# Epoch: 18, Iteration: 0, Loss: 0.6976007223129272
# Epoch: 18, Iteration: 10, Loss: 0.7946629524230957
# Epoch 18 completed in 398.11 seconds, mean loss: 0.777321036045368
# Epoch: 19, Iteration: 0, Loss: 0.8136855959892273
# Epoch: 19, Iteration: 10, Loss: 0.8290578722953796
# Epoch 19 completed in 401.62 seconds, mean loss: 0.7492410907378564
# Epoch: 20, Iteration: 0, Loss: 0.8435578942298889
# Epoch: 20, Iteration: 10, Loss: 0.7049059867858887
# Epoch 20 completed in 378.95 seconds, mean loss: 0.7702669409605173
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_20.pt
# Epoch: 21, Iteration: 0, Loss: 0.6635908484458923
# Epoch: 21, Iteration: 10, Loss: 0.6448273062705994
# Epoch 21 completed in 378.98 seconds, mean loss: 0.7223952596004193
# Epoch: 22, Iteration: 0, Loss: 0.7138159871101379
# Epoch: 22, Iteration: 10, Loss: 0.6458412408828735
# Epoch 22 completed in 382.93 seconds, mean loss: 0.7053098082542419
# Epoch: 23, Iteration: 0, Loss: 0.6818824410438538
# Epoch: 23, Iteration: 10, Loss: 0.756624698638916
# Epoch 23 completed in 403.28 seconds, mean loss: 0.7088365600659297
# Epoch: 24, Iteration: 0, Loss: 0.7429490685462952
# Epoch: 24, Iteration: 10, Loss: 0.6553916335105896
# Epoch 24 completed in 406.09 seconds, mean loss: 0.705315635754512
# Epoch: 25, Iteration: 0, Loss: 0.6258654594421387
# Epoch: 25, Iteration: 10, Loss: 0.7710143327713013
# Epoch 25 completed in 405.69 seconds, mean loss: 0.7050323990675119
# Epoch: 26, Iteration: 0, Loss: 0.6804662346839905
# Epoch: 26, Iteration: 10, Loss: 0.6639279723167419
# Epoch 26 completed in 391.47 seconds, mean loss: 0.6793003128125117
# Epoch: 27, Iteration: 0, Loss: 0.7150705456733704
# Epoch: 27, Iteration: 10, Loss: 0.6764110922813416
# Epoch 27 completed in 402.13 seconds, mean loss: 0.6765441711132343
# Epoch: 28, Iteration: 0, Loss: 0.6253562569618225
# Epoch: 28, Iteration: 10, Loss: 0.7503836154937744
# Epoch 28 completed in 391.95 seconds, mean loss: 0.6900277687953069
# Epoch: 29, Iteration: 0, Loss: 0.6516196131706238
# Epoch: 29, Iteration: 10, Loss: 0.6107376217842102
# Epoch 29 completed in 437.07 seconds, mean loss: 0.6501596249066867
# Epoch: 30, Iteration: 0, Loss: 0.6029880046844482
# Epoch: 30, Iteration: 10, Loss: 0.6536294221878052
# Epoch 30 completed in 389.35 seconds, mean loss: 0.6416206864210275
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_30.pt
# Epoch: 31, Iteration: 0, Loss: 0.4801807701587677
# Epoch: 31, Iteration: 10, Loss: 0.6752198338508606
# Epoch 31 completed in 403.77 seconds, mean loss: 0.625001290669808
# Epoch: 32, Iteration: 0, Loss: 0.6356050968170166
# Epoch: 32, Iteration: 10, Loss: 0.56196528673172
# Epoch 32 completed in 385.40 seconds, mean loss: 0.648961067199707
# Epoch: 33, Iteration: 0, Loss: 0.6522433757781982
# Epoch: 33, Iteration: 10, Loss: 0.5140524506568909
# Epoch 33 completed in 366.82 seconds, mean loss: 0.6175550635044391
# Epoch: 34, Iteration: 0, Loss: 0.6586437225341797
# Epoch: 34, Iteration: 10, Loss: 0.6523752212524414
# Epoch 34 completed in 398.13 seconds, mean loss: 0.6206876704326043
# Epoch: 35, Iteration: 0, Loss: 0.6615838408470154
# Epoch: 35, Iteration: 10, Loss: 0.5912893414497375
# Epoch 35 completed in 418.70 seconds, mean loss: 0.6142493394704965
# Epoch: 36, Iteration: 0, Loss: 0.6254464983940125
# Epoch: 36, Iteration: 10, Loss: 0.6032384037971497
# Epoch 36 completed in 400.33 seconds, mean loss: 0.6010257510038522
# Epoch: 37, Iteration: 0, Loss: 0.5951438546180725
# Epoch: 37, Iteration: 10, Loss: 0.6681913733482361
# Epoch 37 completed in 400.32 seconds, mean loss: 0.6097200604585501
# Epoch: 38, Iteration: 0, Loss: 0.6569703221321106
# Epoch: 38, Iteration: 10, Loss: 0.7091913819313049
# Epoch 38 completed in 406.23 seconds, mean loss: 0.6147094804507035
# Epoch: 39, Iteration: 0, Loss: 0.6859405636787415
# Epoch: 39, Iteration: 10, Loss: 0.6937301158905029
# Epoch 39 completed in 385.86 seconds, mean loss: 0.637585332760444
# Epoch: 40, Iteration: 0, Loss: 0.5650950074195862
# Epoch: 40, Iteration: 10, Loss: 0.6970662474632263
# Epoch 40 completed in 395.86 seconds, mean loss: 0.6120944504554455
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_40.pt
# Epoch: 41, Iteration: 0, Loss: 0.5749379396438599
# Epoch: 41, Iteration: 10, Loss: 0.7274459600448608
# Epoch 41 completed in 377.90 seconds, mean loss: 0.6080673612081088
# Epoch: 42, Iteration: 0, Loss: 0.5364454388618469
# Epoch: 42, Iteration: 10, Loss: 0.44416263699531555
# Epoch 42 completed in 404.98 seconds, mean loss: 0.582305507018016
# Epoch: 43, Iteration: 0, Loss: 0.6075757145881653
# Epoch: 43, Iteration: 10, Loss: 0.5950182676315308
# Epoch 43 completed in 383.53 seconds, mean loss: 0.5866745022627023
# Epoch: 44, Iteration: 0, Loss: 0.6603899002075195
# Epoch: 44, Iteration: 10, Loss: 0.5967419743537903
# Epoch 44 completed in 405.36 seconds, mean loss: 0.5800016935055072
# Epoch: 45, Iteration: 0, Loss: 0.6045459508895874
# Epoch: 45, Iteration: 10, Loss: 0.47509464621543884
# Epoch 45 completed in 405.67 seconds, mean loss: 0.561821712897374
# Epoch: 46, Iteration: 0, Loss: 0.5905641913414001
# Epoch: 46, Iteration: 10, Loss: 0.5611125230789185
# Epoch 46 completed in 397.62 seconds, mean loss: 0.5543844310136942
# Epoch: 47, Iteration: 0, Loss: 0.5091224312782288
# Epoch: 47, Iteration: 10, Loss: 0.5301747918128967
# Epoch 47 completed in 409.38 seconds, mean loss: 0.5831315036003406
# Epoch: 48, Iteration: 0, Loss: 0.429063081741333
# Epoch: 48, Iteration: 10, Loss: 0.5853440165519714
# Epoch 48 completed in 410.07 seconds, mean loss: 0.5632749131092658
# Epoch: 49, Iteration: 0, Loss: 0.5704550743103027
# Epoch: 49, Iteration: 10, Loss: 0.42707905173301697
# Epoch 49 completed in 399.54 seconds, mean loss: 0.5537806818118463
# Epoch: 50, Iteration: 0, Loss: 0.5238555669784546
# Epoch: 50, Iteration: 10, Loss: 0.5977428555488586
# Epoch 50 completed in 391.96 seconds, mean loss: 0.548771259876398
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_50.pt
# Epoch: 51, Iteration: 0, Loss: 0.5901974439620972
# Epoch: 51, Iteration: 10, Loss: 0.5295736789703369
# Epoch 51 completed in 395.06 seconds, mean loss: 0.5496366872237279
# Epoch: 52, Iteration: 0, Loss: 0.5655742287635803
# Epoch: 52, Iteration: 10, Loss: 0.40386301279067993
# Epoch 52 completed in 398.34 seconds, mean loss: 0.5460101045095004
# Epoch: 53, Iteration: 0, Loss: 0.6475110054016113
# Epoch: 53, Iteration: 10, Loss: 0.49198952317237854
# Epoch 53 completed in 389.24 seconds, mean loss: 0.5479679978810824
# Epoch: 54, Iteration: 0, Loss: 0.4208396375179291
# Epoch: 54, Iteration: 10, Loss: 0.5527483820915222
# Epoch 54 completed in 409.08 seconds, mean loss: 0.5380209707296811
# Epoch: 55, Iteration: 0, Loss: 0.6131729483604431
# Epoch: 55, Iteration: 10, Loss: 0.6171985268592834
# Epoch 55 completed in 397.60 seconds, mean loss: 0.5390324615515195
# Epoch: 56, Iteration: 0, Loss: 0.5821128487586975
# Epoch: 56, Iteration: 10, Loss: 0.4469272196292877
# Epoch 56 completed in 408.86 seconds, mean loss: 0.5204107692608466
# Epoch: 57, Iteration: 0, Loss: 0.5086144804954529
# Epoch: 57, Iteration: 10, Loss: 0.5251906514167786
# Epoch 57 completed in 401.51 seconds, mean loss: 0.502127794119028
# Epoch: 58, Iteration: 0, Loss: 0.4797215461730957
# Epoch: 58, Iteration: 10, Loss: 0.4232478737831116
# Epoch 58 completed in 397.50 seconds, mean loss: 0.5154426097869873
# Epoch: 59, Iteration: 0, Loss: 0.47490155696868896
# Epoch: 59, Iteration: 10, Loss: 0.5361288189888
# Epoch 59 completed in 391.26 seconds, mean loss: 0.517137736082077
# Epoch: 60, Iteration: 0, Loss: 0.4984003007411957
# Epoch: 60, Iteration: 10, Loss: 0.49105462431907654
# Epoch 60 completed in 407.78 seconds, mean loss: 0.5169188449015985
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_60.pt
# Epoch: 61, Iteration: 0, Loss: 0.37718284130096436
# Epoch: 61, Iteration: 10, Loss: 0.44957444071769714
# Epoch 61 completed in 384.52 seconds, mean loss: 0.5110645294189453
# Epoch: 62, Iteration: 0, Loss: 0.3958843946456909
# Epoch: 62, Iteration: 10, Loss: 0.5128145813941956
# Epoch 62 completed in 381.48 seconds, mean loss: 0.5192405168826764
# Epoch: 63, Iteration: 0, Loss: 0.5769233703613281
# Epoch: 63, Iteration: 10, Loss: 0.5766140818595886
# Epoch 63 completed in 403.82 seconds, mean loss: 0.5025330346364242
# Epoch: 64, Iteration: 0, Loss: 0.5018143653869629
# Epoch: 64, Iteration: 10, Loss: 0.5585376024246216
# Epoch 64 completed in 390.75 seconds, mean loss: 0.49767709924624515
# Epoch: 65, Iteration: 0, Loss: 0.507601261138916
# Epoch: 65, Iteration: 10, Loss: 0.5382716059684753
# Epoch 65 completed in 403.31 seconds, mean loss: 0.5178494499279902
# Epoch: 66, Iteration: 0, Loss: 0.47722628712654114
# Epoch: 66, Iteration: 10, Loss: 0.4762088358402252
# Epoch 66 completed in 406.59 seconds, mean loss: 0.49680373760370106
# Epoch: 67, Iteration: 0, Loss: 0.464712530374527
# Epoch: 67, Iteration: 10, Loss: 0.5227485299110413
# Epoch 67 completed in 397.61 seconds, mean loss: 0.48282655156575716
# Epoch: 68, Iteration: 0, Loss: 0.4299756586551666
# Epoch: 68, Iteration: 10, Loss: 0.5517227053642273
# Epoch 68 completed in 394.32 seconds, mean loss: 0.48476820954909694
# Epoch: 69, Iteration: 0, Loss: 0.5015261173248291
# Epoch: 69, Iteration: 10, Loss: 0.44688645005226135
# Epoch 69 completed in 417.02 seconds, mean loss: 0.48383893645726717
# Epoch: 70, Iteration: 0, Loss: 0.4374638497829437
# Epoch: 70, Iteration: 10, Loss: 0.42519596219062805
# Epoch 70 completed in 389.05 seconds, mean loss: 0.49582085471886855
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_70.pt
# Epoch: 71, Iteration: 0, Loss: 0.5251740217208862
# Epoch: 71, Iteration: 10, Loss: 0.47967764735221863
# Epoch 71 completed in 396.10 seconds, mean loss: 0.4773898445642911
# Epoch: 72, Iteration: 0, Loss: 0.4958922266960144
# Epoch: 72, Iteration: 10, Loss: 0.40980494022369385
# Epoch 72 completed in 405.49 seconds, mean loss: 0.4908002248177162
# Epoch: 73, Iteration: 0, Loss: 0.46825501322746277
# Epoch: 73, Iteration: 10, Loss: 0.543994665145874
# Epoch 73 completed in 402.77 seconds, mean loss: 0.484797654243616
# Epoch: 74, Iteration: 0, Loss: 0.462988942861557
# Epoch: 74, Iteration: 10, Loss: 0.4812130331993103
# Epoch 74 completed in 410.85 seconds, mean loss: 0.480320196885329
# Epoch: 75, Iteration: 0, Loss: 0.4345308244228363
# Epoch: 75, Iteration: 10, Loss: 0.5197172164916992
# Epoch 75 completed in 391.67 seconds, mean loss: 0.473247046654041
# Epoch: 76, Iteration: 0, Loss: 0.39346274733543396
# Epoch: 76, Iteration: 10, Loss: 0.5036939978599548
# Epoch 76 completed in 407.18 seconds, mean loss: 0.46823506630384004
# Epoch: 77, Iteration: 0, Loss: 0.5183419585227966
# Epoch: 77, Iteration: 10, Loss: 0.4820752739906311
# Epoch 77 completed in 383.10 seconds, mean loss: 0.475739082464805
# Epoch: 78, Iteration: 0, Loss: 0.4472275376319885
# Epoch: 78, Iteration: 10, Loss: 0.44742628931999207
# Epoch 78 completed in 406.20 seconds, mean loss: 0.4643639119771811
# Epoch: 79, Iteration: 0, Loss: 0.4192001223564148
# Epoch: 79, Iteration: 10, Loss: 0.31798362731933594
# Epoch 79 completed in 398.21 seconds, mean loss: 0.4598858608649327
# Epoch: 80, Iteration: 0, Loss: 0.4090937077999115
# Epoch: 80, Iteration: 10, Loss: 0.4526677429676056
# Epoch 80 completed in 389.44 seconds, mean loss: 0.458408195238847
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_80.pt
# Epoch: 81, Iteration: 0, Loss: 0.36312273144721985
# Epoch: 81, Iteration: 10, Loss: 0.5350104570388794
# Epoch 81 completed in 393.76 seconds, mean loss: 0.4628989031681648
# Epoch: 82, Iteration: 0, Loss: 0.542460024356842
# Epoch: 82, Iteration: 10, Loss: 0.4182954430580139
# Epoch 82 completed in 410.59 seconds, mean loss: 0.49094844781435454
# Epoch: 83, Iteration: 0, Loss: 0.36942559480667114
# Epoch: 83, Iteration: 10, Loss: 0.48573774099349976
# Epoch 83 completed in 396.72 seconds, mean loss: 0.4664700191754561
# Epoch: 84, Iteration: 0, Loss: 0.39039021730422974
# Epoch: 84, Iteration: 10, Loss: 0.4794248640537262
# Epoch 84 completed in 395.84 seconds, mean loss: 0.45435545765436613
# Epoch: 85, Iteration: 0, Loss: 0.4819868505001068
# Epoch: 85, Iteration: 10, Loss: 0.514748752117157
# Epoch 85 completed in 396.08 seconds, mean loss: 0.45216421209848845
# Epoch: 86, Iteration: 0, Loss: 0.44263628125190735
# Epoch: 86, Iteration: 10, Loss: 0.500869870185852
# Epoch 86 completed in 404.72 seconds, mean loss: 0.461768606534371
# Epoch: 87, Iteration: 0, Loss: 0.47998547554016113
# Epoch: 87, Iteration: 10, Loss: 0.42678865790367126
# Epoch 87 completed in 399.42 seconds, mean loss: 0.44837671976823074
# Epoch: 88, Iteration: 0, Loss: 0.5024363994598389
# Epoch: 88, Iteration: 10, Loss: 0.4955580234527588
# Epoch 88 completed in 395.71 seconds, mean loss: 0.4451791804570418
# Epoch: 89, Iteration: 0, Loss: 0.42808693647384644
# Epoch: 89, Iteration: 10, Loss: 0.45693308115005493
# Epoch 89 completed in 405.32 seconds, mean loss: 0.4649082926603464
# Epoch: 90, Iteration: 0, Loss: 0.43567949533462524
# Epoch: 90, Iteration: 10, Loss: 0.41543033719062805
# Epoch 90 completed in 400.40 seconds, mean loss: 0.442309721158101
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_90.pt
# Epoch: 91, Iteration: 0, Loss: 0.3319537043571472
# Epoch: 91, Iteration: 10, Loss: 0.47695308923721313
# Epoch 91 completed in 393.83 seconds, mean loss: 0.44650469147242033
# Epoch: 92, Iteration: 0, Loss: 0.4072573482990265
# Epoch: 92, Iteration: 10, Loss: 0.4051651060581207
# Epoch 92 completed in 395.33 seconds, mean loss: 0.44262667344166684
# Epoch: 93, Iteration: 0, Loss: 0.37984198331832886
# Epoch: 93, Iteration: 10, Loss: 0.44979843497276306
# Epoch 93 completed in 422.01 seconds, mean loss: 0.4578290283679962
# Epoch: 94, Iteration: 0, Loss: 0.48064056038856506
# Epoch: 94, Iteration: 10, Loss: 0.48966917395591736
# Epoch 94 completed in 396.48 seconds, mean loss: 0.4361368394815005
# Epoch: 95, Iteration: 0, Loss: 0.38849106431007385
# Epoch: 95, Iteration: 10, Loss: 0.47152891755104065
# Epoch 95 completed in 385.98 seconds, mean loss: 0.44245604368356556
# Epoch: 96, Iteration: 0, Loss: 0.42253679037094116
# Epoch: 96, Iteration: 10, Loss: 0.4871000349521637
# Epoch 96 completed in 392.10 seconds, mean loss: 0.4285552960175734
# Epoch: 97, Iteration: 0, Loss: 0.4773235619068146
# Epoch: 97, Iteration: 10, Loss: 0.48443126678466797
# Epoch 97 completed in 393.71 seconds, mean loss: 0.4460854461559883
# Epoch: 98, Iteration: 0, Loss: 0.40115466713905334
# Epoch: 98, Iteration: 10, Loss: 0.4469941258430481
# Epoch 98 completed in 405.65 seconds, mean loss: 0.4252225137673892
# Epoch: 99, Iteration: 0, Loss: 0.43419358134269714
# Epoch: 99, Iteration: 10, Loss: 0.339689701795578
# Epoch 99 completed in 400.35 seconds, mean loss: 0.450495923940952
# Epoch: 100, Iteration: 0, Loss: 0.39631131291389465
# Epoch: 100, Iteration: 10, Loss: 0.5211482644081116
# Epoch 100 completed in 407.87 seconds, mean loss: 0.42617348065743077
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_100.pt
# Epoch: 101, Iteration: 0, Loss: 0.4948408901691437
# Epoch: 101, Iteration: 10, Loss: 0.4277339577674866
# Epoch 101 completed in 391.96 seconds, mean loss: 0.4398161700138679
# Epoch: 102, Iteration: 0, Loss: 0.313496857881546
# Epoch: 102, Iteration: 10, Loss: 0.4819321930408478
# Epoch 102 completed in 400.71 seconds, mean loss: 0.429551906310595
# Epoch: 103, Iteration: 0, Loss: 0.4328087568283081
# Epoch: 103, Iteration: 10, Loss: 0.4479459524154663
# Epoch 103 completed in 373.34 seconds, mean loss: 0.43679486558987546
# Epoch: 104, Iteration: 0, Loss: 0.3425140976905823
# Epoch: 104, Iteration: 10, Loss: 0.4440014958381653
# Epoch 104 completed in 391.24 seconds, mean loss: 0.4154859483242035
# Epoch: 105, Iteration: 0, Loss: 0.4021851420402527
# Epoch: 105, Iteration: 10, Loss: 0.40956947207450867
# Epoch 105 completed in 394.06 seconds, mean loss: 0.4290367043935336
# Epoch: 106, Iteration: 0, Loss: 0.41107305884361267
# Epoch: 106, Iteration: 10, Loss: 0.39190971851348877
# Epoch 106 completed in 394.55 seconds, mean loss: 0.41625120777350205
# Epoch: 107, Iteration: 0, Loss: 0.4175627529621124
# Epoch: 107, Iteration: 10, Loss: 0.3901773989200592
# Epoch 107 completed in 401.29 seconds, mean loss: 0.41285377053114086
# Epoch: 108, Iteration: 0, Loss: 0.4089272618293762
# Epoch: 108, Iteration: 10, Loss: 0.4325627386569977
# Epoch 108 completed in 394.94 seconds, mean loss: 0.41861910086411697
# Epoch: 109, Iteration: 0, Loss: 0.3771601617336273
# Epoch: 109, Iteration: 10, Loss: 0.43887656927108765
# Epoch 109 completed in 387.62 seconds, mean loss: 0.42553856051885164
# Epoch: 110, Iteration: 0, Loss: 0.40980178117752075
# Epoch: 110, Iteration: 10, Loss: 0.3691674768924713
# Epoch 110 completed in 403.37 seconds, mean loss: 0.4030873500383817
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_110.pt
# Epoch: 111, Iteration: 0, Loss: 0.4519473612308502
# Epoch: 111, Iteration: 10, Loss: 0.4083518385887146
# Epoch 111 completed in 404.69 seconds, mean loss: 0.3996166701500232
# Epoch: 112, Iteration: 0, Loss: 0.4494822919368744
# Epoch: 112, Iteration: 10, Loss: 0.3905943036079407
# Epoch 112 completed in 399.76 seconds, mean loss: 0.4125050673118004
# Epoch: 113, Iteration: 0, Loss: 0.3258262872695923
# Epoch: 113, Iteration: 10, Loss: 0.45677056908607483
# Epoch 113 completed in 385.97 seconds, mean loss: 0.42208904257187474
# Epoch: 114, Iteration: 0, Loss: 0.3683878779411316
# Epoch: 114, Iteration: 10, Loss: 0.39381152391433716
# Epoch 114 completed in 397.52 seconds, mean loss: 0.42763917262737566
# Epoch: 115, Iteration: 0, Loss: 0.4735954701900482
# Epoch: 115, Iteration: 10, Loss: 0.3924243450164795
# Epoch 115 completed in 390.53 seconds, mean loss: 0.40369938199336713
# Epoch: 116, Iteration: 0, Loss: 0.4225651025772095
# Epoch: 116, Iteration: 10, Loss: 0.37399905920028687
# Epoch 116 completed in 400.19 seconds, mean loss: 0.4039694368839264
# Epoch: 117, Iteration: 0, Loss: 0.4006555676460266
# Epoch: 117, Iteration: 10, Loss: 0.41645243763923645
# Epoch 117 completed in 374.35 seconds, mean loss: 0.394507130751243
# Epoch: 118, Iteration: 0, Loss: 0.3617706000804901
# Epoch: 118, Iteration: 10, Loss: 0.38968658447265625
# Epoch 118 completed in 382.35 seconds, mean loss: 0.40704500445952785
# Epoch: 119, Iteration: 0, Loss: 0.42976924777030945
# Epoch: 119, Iteration: 10, Loss: 0.3345060646533966
# Epoch 119 completed in 401.69 seconds, mean loss: 0.4133312885577862
# Epoch: 120, Iteration: 0, Loss: 0.37930864095687866
# Epoch: 120, Iteration: 10, Loss: 0.41774484515190125
# Epoch 120 completed in 405.59 seconds, mean loss: 0.3944848867563101
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_120.pt
# Epoch: 121, Iteration: 0, Loss: 0.4073695242404938
# Epoch: 121, Iteration: 10, Loss: 0.442993700504303
# Epoch 121 completed in 387.56 seconds, mean loss: 0.40312268413030183
# Epoch: 122, Iteration: 0, Loss: 0.40144678950309753
# Epoch: 122, Iteration: 10, Loss: 0.415051132440567
# Epoch 122 completed in 397.38 seconds, mean loss: 0.39510289293069106
# Epoch: 123, Iteration: 0, Loss: 0.35041671991348267
# Epoch: 123, Iteration: 10, Loss: 0.4318764805793762
# Epoch 123 completed in 399.61 seconds, mean loss: 0.3969857165446648
# Epoch: 124, Iteration: 0, Loss: 0.4153001308441162
# Epoch: 124, Iteration: 10, Loss: 0.3823564350605011
# Epoch 124 completed in 401.94 seconds, mean loss: 0.39546006000958955
# Epoch: 125, Iteration: 0, Loss: 0.4157933294773102
# Epoch: 125, Iteration: 10, Loss: 0.37262216210365295
# Epoch 125 completed in 396.23 seconds, mean loss: 0.3843518472634829
# Epoch: 126, Iteration: 0, Loss: 0.3748587965965271
# Epoch: 126, Iteration: 10, Loss: 0.44797882437705994
# Epoch 126 completed in 398.93 seconds, mean loss: 0.3873241383295793
# Epoch: 127, Iteration: 0, Loss: 0.4573262631893158
# Epoch: 127, Iteration: 10, Loss: 0.35212287306785583
# Epoch 127 completed in 394.45 seconds, mean loss: 0.4150189803196834
# Epoch: 128, Iteration: 0, Loss: 0.3122568726539612
# Epoch: 128, Iteration: 10, Loss: 0.3850198984146118
# Epoch 128 completed in 392.37 seconds, mean loss: 0.39220628371605504
# Epoch: 129, Iteration: 0, Loss: 0.43370941281318665
# Epoch: 129, Iteration: 10, Loss: 0.3960200548171997
# Epoch 129 completed in 393.44 seconds, mean loss: 0.4140668626015003
# Epoch: 130, Iteration: 0, Loss: 0.32962989807128906
# Epoch: 130, Iteration: 10, Loss: 0.37603989243507385
# Epoch 130 completed in 399.98 seconds, mean loss: 0.3993372985949883
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_130.pt
# Epoch: 131, Iteration: 0, Loss: 0.4061579704284668
# Epoch: 131, Iteration: 10, Loss: 0.4254465699195862
# Epoch 131 completed in 395.98 seconds, mean loss: 0.40031989262654233
# Epoch: 132, Iteration: 0, Loss: 0.3364731967449188
# Epoch: 132, Iteration: 10, Loss: 0.37477704882621765
# Epoch 132 completed in 393.22 seconds, mean loss: 0.39533156844285816
# Epoch: 133, Iteration: 0, Loss: 0.4357164800167084
# Epoch: 133, Iteration: 10, Loss: 0.41666102409362793
# Epoch 133 completed in 389.63 seconds, mean loss: 0.39471315420590913
# Epoch: 134, Iteration: 0, Loss: 0.3814524710178375
# Epoch: 134, Iteration: 10, Loss: 0.3621019423007965
# Epoch 134 completed in 398.13 seconds, mean loss: 0.3818221413172208
# Epoch: 135, Iteration: 0, Loss: 0.4060401916503906
# Epoch: 135, Iteration: 10, Loss: 0.35227862000465393
# Epoch 135 completed in 392.25 seconds, mean loss: 0.39045878557058483
# Epoch: 136, Iteration: 0, Loss: 0.38196897506713867
# Epoch: 136, Iteration: 10, Loss: 0.2987566292285919
# Epoch 136 completed in 397.89 seconds, mean loss: 0.3899444066561185
# Epoch: 137, Iteration: 0, Loss: 0.3489783704280853
# Epoch: 137, Iteration: 10, Loss: 0.4076657295227051
# Epoch 137 completed in 405.86 seconds, mean loss: 0.3835084621722882
# Epoch: 138, Iteration: 0, Loss: 0.36536577343940735
# Epoch: 138, Iteration: 10, Loss: 0.3997080624103546
# Epoch 138 completed in 387.29 seconds, mean loss: 0.4022882924630092
# Epoch: 139, Iteration: 0, Loss: 0.36245059967041016
# Epoch: 139, Iteration: 10, Loss: 0.3804885745048523
# Epoch 139 completed in 403.32 seconds, mean loss: 0.3786269403420962
# Epoch: 140, Iteration: 0, Loss: 0.34827733039855957
# Epoch: 140, Iteration: 10, Loss: 0.37781602144241333
# Epoch 140 completed in 392.22 seconds, mean loss: 0.38449841050001293
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_140.pt
# Epoch: 141, Iteration: 0, Loss: 0.3702523410320282
# Epoch: 141, Iteration: 10, Loss: 0.3981553316116333
# Epoch 141 completed in 394.25 seconds, mean loss: 0.36715916716135466
# Epoch: 142, Iteration: 0, Loss: 0.3534201383590698
# Epoch: 142, Iteration: 10, Loss: 0.34292495250701904
# Epoch 142 completed in 399.65 seconds, mean loss: 0.36153754133444566
# Epoch: 143, Iteration: 0, Loss: 0.3583568334579468
# Epoch: 143, Iteration: 10, Loss: 0.3932283818721771
# Epoch 143 completed in 392.99 seconds, mean loss: 0.3832319126679347
# Epoch: 144, Iteration: 0, Loss: 0.38085514307022095
# Epoch: 144, Iteration: 10, Loss: 0.3811004161834717
# Epoch 144 completed in 401.51 seconds, mean loss: 0.36108476382035476
# Epoch: 145, Iteration: 0, Loss: 0.3861045241355896
# Epoch: 145, Iteration: 10, Loss: 0.32511869072914124
# Epoch 145 completed in 383.80 seconds, mean loss: 0.3778183047588055
# Epoch: 146, Iteration: 0, Loss: 0.28042173385620117
# Epoch: 146, Iteration: 10, Loss: 0.37824392318725586
# Epoch 146 completed in 395.05 seconds, mean loss: 0.3591221227095677
# Epoch: 147, Iteration: 0, Loss: 0.3654998242855072
# Epoch: 147, Iteration: 10, Loss: 0.33345815539360046
# Epoch 147 completed in 390.62 seconds, mean loss: 0.36103824698008025
# Epoch: 148, Iteration: 0, Loss: 0.37602728605270386
# Epoch: 148, Iteration: 10, Loss: 0.36706796288490295
# Epoch 148 completed in 405.24 seconds, mean loss: 0.362089393230585
# Epoch: 149, Iteration: 0, Loss: 0.4208345413208008
# Epoch: 149, Iteration: 10, Loss: 0.3521120846271515
# Epoch 149 completed in 379.20 seconds, mean loss: 0.3672033204482152
# Epoch: 150, Iteration: 0, Loss: 0.3349064290523529
# Epoch: 150, Iteration: 10, Loss: 0.370351105928421
# Epoch 150 completed in 389.29 seconds, mean loss: 0.3797650704017052
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_150.pt
# Epoch: 151, Iteration: 0, Loss: 0.36181262135505676
# Epoch: 151, Iteration: 10, Loss: 0.4441812336444855
# Epoch 151 completed in 379.81 seconds, mean loss: 0.38668892016777623
# Epoch: 152, Iteration: 0, Loss: 0.4126233160495758
# Epoch: 152, Iteration: 10, Loss: 0.4173750579357147
# Epoch 152 completed in 405.72 seconds, mean loss: 0.37861544581559986
# Epoch: 153, Iteration: 0, Loss: 0.2943112552165985
# Epoch: 153, Iteration: 10, Loss: 0.40071696043014526
# Epoch 153 completed in 383.48 seconds, mean loss: 0.371518449141429
# Epoch: 154, Iteration: 0, Loss: 0.3706507980823517
# Epoch: 154, Iteration: 10, Loss: 0.41784796118736267
# Epoch 154 completed in 406.22 seconds, mean loss: 0.36503506853030276
# Epoch: 155, Iteration: 0, Loss: 0.34137946367263794
# Epoch: 155, Iteration: 10, Loss: 0.40427348017692566
# Epoch 155 completed in 392.43 seconds, mean loss: 0.36331944511486935
# Epoch: 156, Iteration: 0, Loss: 0.3440139591693878
# Epoch: 156, Iteration: 10, Loss: 0.3345777094364166
# Epoch 156 completed in 389.06 seconds, mean loss: 0.36350974669823277
# Epoch: 157, Iteration: 0, Loss: 0.39168745279312134
# Epoch: 157, Iteration: 10, Loss: 0.3622385859489441
# Epoch 157 completed in 384.40 seconds, mean loss: 0.36010260306871855
# Epoch: 158, Iteration: 0, Loss: 0.3249458968639374
# Epoch: 158, Iteration: 10, Loss: 0.3454669117927551
# Epoch 158 completed in 384.81 seconds, mean loss: 0.368305158156615
# Epoch: 159, Iteration: 0, Loss: 0.35230299830436707
# Epoch: 159, Iteration: 10, Loss: 0.33610424399375916
# Epoch 159 completed in 407.34 seconds, mean loss: 0.35632203404720014
# Epoch: 160, Iteration: 0, Loss: 0.33706504106521606
# Epoch: 160, Iteration: 10, Loss: 0.39293015003204346
# Epoch 160 completed in 391.56 seconds, mean loss: 0.35341946666057295
# Checkpoint saved at ./pretrained_check_points/checkpoint_epoch_160.pt

# %%
phoneme_sequence,end_time = read_and_convert_phonemes(tacotron_file_list[0]['phonetic_file'])
print(phoneme_sequence)
length = [len(phoneme_sequence)]
inputs = torch.tensor(phoneme_sequence, dtype=torch.int).unsqueeze(0).to(device)
input_lengths = torch.tensor(length, dtype=torch.int).to(device)
print(inputs.shape)
print(input_lengths)
model.eval()

with torch.no_grad():
    mel_outputs, mel_lengths, alignments = model.infer(inputs, input_lengths)

print("Mel Outputs Postnet:", mel_outputs)
print("Mel Lengths:", mel_lengths)
print("Alignments:", alignments)
print(mel_outputs.shape)
play_audio = play_mel_audio(mel_outputs[0])
play_audio
# Out:
# [38, 17, 38, 31, 29, 13, 2, 23, 38, 31, 17, 28, 25, 29, 38, 22, 0, 28, 30, 22, 2, 21, 25, 15, 38, 2, 23, 17, 38, 14, 1, 29, 38, 10, 6, 23, 6, 38, 39]
# torch.Size([1, 39])
# tensor([39], device='cuda:0', dtype=torch.int32)
# Mel Outputs Postnet: tensor([[[-8.4239, -8.4095, -8.4378,  ..., -7.6519, -7.9095, -4.9079],
#          [-9.1067, -9.1264, -9.1571,  ..., -7.8923, -8.2115, -5.2883],
#          [-9.1461, -9.0507, -9.0928,  ..., -7.8754, -8.2913, -5.4852],
#          ...,
#          [-9.7379, -9.8588, -9.8919,  ..., -9.8403, -9.5660, -5.5531],
#          [-9.7344, -9.8989, -9.9399,  ..., -9.8160, -9.5144, -5.6302],
#          [-9.7457, -9.9287, -9.9340,  ..., -9.6717, -9.3306, -5.4937]]],
#        device='cuda:0')
# Mel Lengths: tensor([167], device='cuda:0', dtype=torch.int32)
# Alignments: tensor([[[9.9145e-01, 9.2030e-04, 7.1450e-05,  ..., 2.3049e-06,
#           1.5271e-08, 2.7900e-08],
#          [9.9015e-01, 1.6022e-03, 7.8949e-05,  ..., 1.0633e-05,
#           3.2327e-08, 4.3604e-09],
#          [9.7868e-01, 1.3775e-03, 5.2440e-05,  ..., 1.3852e-05,
#           6.7205e-08, 7.9865e-09],
#          ...,
#          [1.4639e-02, 1.7112e-02, 1.3930e-02,  ..., 1.1002e-01,
#           8.2718e-04, 5.6819e-05],
#          [1.0884e-02, 9.6154e-03, 7.2739e-03,  ..., 1.6061e-01,
#           1.4403e-03, 1.7242e-04],
#          [1.2469e-02, 5.7752e-03, 4.3169e-03,  ..., 2.6438e-01,
#           5.0080e-03, 5.4525e-04]]], device='cuda:0')
# torch.Size([1, 80, 168])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hparams = {
    'n_mel_channels': 80,
    'n_symbols': 148,
    'symbols_embedding_dim': 512,
    'encoder_kernel_size': 5,
    'encoder_n_convolutions': 3,
    'encoder_embedding_dim': 512,
    'attention_rnn_dim': 1024,
    'attention_dim': 128,
    'attention_location_n_filters': 32,
    'attention_location_kernel_size': 31,
    'n_frames_per_step': 1,
    'decoder_rnn_dim': 1024,
    'prenet_dim': 256,
    'max_decoder_steps': 1000,
    'gate_threshold': 0.5,
    'p_attention_dropout': 0.1,
    'p_decoder_dropout': 0.1,
    'postnet_embedding_dim': 512,
    'postnet_kernel_size': 5,
    'postnet_n_convolutions': 5,
    'decoder_no_early_stopping': False,
    'mask_padding': False
}
model = Tacotron2(**hparams).to(device)
checkpoint = torch.load(os.path.join('./pretrained_check_points/','checkpoint_epoch_160.pt'))

load_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
raw_audio = load_audio_from_path(tacotron_file_list[2]['audio_file'])
print(raw_audio.shape)
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
# torch.Size([53556])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
phoneme_sequence,end_time = read_and_convert_phonemes(tacotron_file_list[2]['phonetic_file'])
print(phoneme_sequence)
length = [len(phoneme_sequence)]
inputs = torch.tensor(phoneme_sequence, dtype=torch.int).unsqueeze(0).to(device)
input_lengths = torch.tensor(length, dtype=torch.int).to(device)
print(inputs.shape)
print(input_lengths)
model.eval()

with torch.no_grad():
    mel_outputs, mel_lengths, alignments = model.infer(inputs, input_lengths)

print("Mel Outputs Postnet:", mel_outputs)
print("Mel Lengths:", mel_lengths)
print("Alignments:", alignments)
print(mel_outputs.shape)
play_audio = play_mel_audio(mel_outputs[0])
play_audio
# Out:
# [38, 4, 38, 14, 7, 35, 8, 5, 22, 29, 5, 35, 28, 21, 38, 12, 26, 29, 17, 15, 38, 2, 23, 21, 5, 38, 8, 5, 22, 29, 5, 38, 8, 2, 38, 27, 28, 4, 0, 28, 6, 9, 18, 15, 38, 39]
# torch.Size([1, 46])
# tensor([46], device='cuda:0', dtype=torch.int32)
# Mel Outputs Postnet: tensor([[[-8.2399, -8.4005, -8.3377,  ..., -8.3925, -8.4731, -8.3337],
#          [-8.7448, -9.0091, -8.9034,  ..., -8.8529, -8.9983, -8.8882],
#          [-8.7093, -8.8331, -8.8990,  ..., -8.9354, -9.1225, -9.1073],
#          ...,
#          [-9.6418, -9.7918, -9.8768,  ..., -9.8933, -9.7992, -9.8151],
#          [-9.5616, -9.6776, -9.7851,  ..., -9.9489, -9.8325, -9.8135],
#          [-9.5142, -9.6656, -9.7307,  ..., -9.9838, -9.8311, -9.7711]]],
#        device='cuda:0')
# Mel Lengths: tensor([195], device='cuda:0', dtype=torch.int32)
# Alignments: tensor([[[9.9596e-01, 9.8525e-04, 5.9685e-05,  ..., 4.4553e-06,
#           5.2562e-09, 9.6908e-09],
#          [9.7584e-01, 1.3790e-03, 2.3620e-04,  ..., 4.9590e-05,
#           6.5433e-08, 4.9425e-08],
#          [9.6278e-01, 1.6840e-03, 3.0200e-04,  ..., 6.9720e-05,
#           3.2715e-07, 3.0509e-07],
#          ...,
#          [4.0723e-02, 8.6632e-03, 8.0838e-03,  ..., 2.3483e-02,
#           3.9837e-04, 9.2661e-05],
#          [1.4630e-02, 4.2319e-03, 5.3144e-03,  ..., 3.1564e-02,
#           1.7961e-04, 1.4783e-05],
#          [2.1989e-03, 8.4968e-03, 4.7928e-03,  ..., 5.3649e-02,
#           3.5809e-04, 4.9663e-05]]], device='cuda:0')
# torch.Size([1, 80, 196])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
