# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import librosa
import torchaudio
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys

from tqdm.auto import tqdm
from IPython.display import Audio

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA version: {torch.version.cuda}")
print(f"CUDNN version: {torch.backends.cudnn.version()}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# cuda
# PyTorch version: 2.3.1
# CUDA version: 12.1
# CUDNN version: 8907
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
file_path = './TIMIT/'
data_path = './TIMIT/data'

train_data = pd.read_csv(os.path.join(file_path, 'train_data.csv'))
test_data = pd.read_csv(os.path.join(file_path, 'test_data.csv'))
df = pd.concat([train_data, test_data])

# %%
audio_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str:
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in audio_files:
            audio_files[filename]={}
        
        if filename in audio_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                audio_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                audio_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                audio_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(audio_files))
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break
# Out:
# 6300
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}

# %%
female_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str and row['speaker_id'].startswith('F'):
        if filename.split('.')[0] in ['SA1','SA2']:
            continue
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in female_files:
            female_files[filename]={}
        
        if filename in female_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                female_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                female_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                female_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(female_files))
# Out:
# 1920

# %%
# TimitBet 61 phoneme mapping to 39 phonemes
# by Lee, K.-F., & Hon, H.-W. (1989). Speaker-independent phone recognition using hidden Markov models. IEEE Transactions on Acoustics, Speech, and Signal Processing, 37(11), 1641–1648. doi:10.1109/29.46546 
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

# %%
from scipy.io.wavfile import read
y1, sr1 = librosa.load('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav', sr=16000)
sr2, y2 = read('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav')
print(f'Shape of audio sequence: {y2.shape}')
print(f'sample rate: {sr2}')
if np.array_equal(y1, y2):
    print('y1=y2')
else:
    print('y1!=y2')
# Out:
# 音频时间序列的形状: (53556,)
# 采样率: 16000
# y1!=y2

# %%
# def compute_mel_spectrogram(y, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
#     mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
#     log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
#     return log_mel_spectrogram

# %%
# mel_y1 = compute_mel_spectrogram(y1[0:1000])
# print(mel_y1[0])

# %%
# !git clone https://github.com/NVIDIA/DeepLearningExamples.git

# %%
waveglow_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/'
sys.path.append(waveglow_path)
tacotron2_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/'
sys.path.append(tacotron2_path)

# %%
from denoiser import Denoiser
from model import WaveGlow
import data_function
import loss_function
from loss_function import WaveGlowLoss
import importlib.util
entrypoints_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/entrypoints.py'

spec = importlib.util.spec_from_file_location("entrypoints", entrypoints_path)
entrypoints = importlib.util.module_from_spec(spec)
sys.modules["entrypoints"] = entrypoints
spec.loader.exec_module(entrypoints)

from entrypoints import nvidia_waveglow

# %%
from scipy.io.wavfile import read
import tacotron2_common.layers as layers
max_wav_value = 32768.0

def compute_mel_spectrogram(audio_data, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
    stft = layers.TacotronSTFT(sampling_rate=16000)
    
    audio_norm = audio_data / max_wav_value
    audio_norm = audio_norm.unsqueeze(0)
    audio_norm = torch.autograd.Variable(audio_norm, requires_grad=False)
    melspec = stft.mel_spectrogram(audio_norm)
    melspec = torch.squeeze(melspec, 0)

    return melspec

def load_audio_from_path(path):
    sampling_rate, data = read(path)
    audio_data = torch.FloatTensor(data.astype(np.float32))

    return audio_data

def compute_mel_from_path(path):
    return compute_mel_spectrogram(load_audio_from_path(path))

# %%
from torch.utils.data import DataLoader

def load_mel_audio(file_path, sr=16000, n_mels=80, n_fft=1024, hop_length=256):

    audio = load_audio_from_path(file_path)
    
    melspec = compute_mel_spectrogram(audio)
    
    return melspec, audio

class MelDataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        mel_spectrogram, audio = load_mel_audio(file_path)
        return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)

file_list = []
for (key,value) in female_files.items():
    file_list.append(value['audio_file'])

dataset = MelDataset(file_list)
train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
dataset[0]
# Out:
# C:\Users\YANG\AppData\Local\Temp\ipykernel_3136\556344903.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)
# (tensor([[ -8.4898,  -8.4369,  -9.0065,  ...,  -6.8391,  -7.0954,  -7.3317],
#          [ -9.8049,  -9.1275,  -9.2912,  ...,  -6.9650,  -6.6273,  -6.6464],
#          [ -9.1401,  -9.1792,  -9.6098,  ...,  -7.8798,  -6.9461,  -6.9621],
#          ...,
#          [ -9.7159, -10.0164, -10.0679,  ...,  -9.3277,  -9.2204,  -9.2737],
#          [ -9.5567,  -9.7603,  -9.9210,  ...,  -9.1527,  -9.1147,  -9.2802],
#          [ -9.4876,  -9.6483,  -9.7763,  ...,  -9.7336,  -9.6742,  -9.6836]],
#         device='cuda:0'),
#  tensor([14., -7., -1.,  ..., -4., -4., -1.], device='cuda:0'))

# %%
n_mel_channels = 80
n_flows = 12
n_group = 8
n_early_every = 4
n_early_size = 2
WN_config = {
    "n_layers": 8,
    "n_channels": 512,
    "kernel_size": 3
}

# waveglow = WaveGlow(n_mel_channels, n_flows, n_group, n_early_every, n_early_size, WN_config)
# waveglow = waveglow.cuda()

waveglow =  nvidia_waveglow(pretrained=True, model_math='fp32')
waveglow = waveglow.cuda()
# Out:
# E:\study_software\anaconda\conda\lib\site-packages\torch\nn\utils\weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
from denoiser import Denoiser
tem_mal = compute_mel_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav').to(device)

with torch.no_grad():
    audio = waveglow.infer(tem_mal.unsqueeze(0).to(device), sigma=0.666)

denoiser = Denoiser(waveglow)
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
audio_numpy = audio_denoised.cpu().numpy()

Audio(audio_numpy, rate=18000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
raw_audio = load_audio_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav')
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

def play_mel_audio(mel_spectrogram):
    with torch.no_grad():
        audio = waveglow.infer(mel_spectrogram.unsqueeze(0).to(device), sigma=1)
    
    denoiser = Denoiser(waveglow)
    audio_denoised = denoiser(audio, strength=0.01)[:, 0]
    audio_numpy = audio_denoised.cpu().numpy()

    return Audio(audio_numpy, rate=18000)

# %%
def read_and_convert_phonemes(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    end_time = 0
    
    phoneme_indices = []
    
    for line in lines:
        parts = line.strip().split()
        
        if len(parts) != 3:
            continue
        end_time = parts[1]
        phoneme = parts[2]
        
        if phoneme in pho61_to_pho39:
            pho39 = pho61_to_pho39[phoneme]
            if pho39 in pho39_to_index:
                index = pho39_to_index[pho39]-1
                phoneme_indices.append(index)
    phoneme_indices.append(39)
    
    return phoneme_indices,end_time

# %%
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break

tacotron_file_list = []
for key,files in female_files.items():
    if len(files) == 3:
        tacotron_file_list.append(files)
print(len(tacotron_file_list))
# Out:
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}
# 990

# %%
class Tacotron2Dataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_paths = self.file_list[idx]
        phone_list, end_time = read_and_convert_phonemes(file_paths['phonetic_file'])
        mel_spectrogram = compute_mel_spectrogram(load_audio_from_path(file_paths['audio_file'][0:int(end_time)]))
        
        phone_tensor = torch.tensor(phone_list, dtype=torch.int).clone().detach()
        mel_tensor = mel_spectrogram.float()
        
        return phone_tensor, mel_tensor, len(phone_list)

# %%
tacotron_dataset = Tacotron2Dataset(tacotron_file_list)
tacotron_dataset[0][1].shape
# Out:
# torch.Size([80, 180])

# %%
from tacotron2.model import Tacotron2
from tacotron2.loss_function import Tacotron2Loss
hparams = {
    'n_mel_channels': 80,
    'n_symbols': 40, 
    'symbols_embedding_dim': 512,
    'encoder_kernel_size': 5,
    'encoder_n_convolutions': 3,
    'encoder_embedding_dim': 512,
    'attention_rnn_dim': 1024,
    'attention_dim': 128,
    'attention_location_n_filters': 32,
    'attention_location_kernel_size': 31,
    'n_frames_per_step': 1,
    'decoder_rnn_dim': 1024,
    'prenet_dim': 256,
    'max_decoder_steps': 1000,
    'gate_threshold': 0.5,
    'p_attention_dropout': 0.1,
    'p_decoder_dropout': 0.1,
    'postnet_embedding_dim': 512,
    'postnet_kernel_size': 5,
    'postnet_n_convolutions': 5,
    'decoder_no_early_stopping': False,
    'mask_padding': False
}
model = Tacotron2(**hparams).to(device)

# %%
# !pip install inflect

# %%
import data_functions
import time
import loss_functions

# continue train

model = Tacotron2(**hparams).to(device)
checkpoint = torch.load(os.path.join('./processed_check_points/','checkpoint_epoch_510.pt'))

load_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['model_state_dict'])
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
print(checkpoint['loss'])
model_name = 'Tacotron2'
criterion = loss_functions.get_loss_function(model_name)
collate_fn = data_functions.get_collate_function(model_name)
train_loader = DataLoader(tacotron_dataset, num_workers=0, shuffle=True, batch_size=64, pin_memory=False, drop_last=False, collate_fn=collate_fn)
batch_to_gpu = data_functions.get_batch_to_gpu(model_name)

epochs = 300 
grad_clip_thresh = 1.0 

model.train()
print(f'load epoch: {load_epoch}')
for epoch in range(load_epoch+1, load_epoch+epochs+1):
    mean_loss = 0
    train_count = 0
    torch.cuda.synchronize()
    epoch_start_time = time.perf_counter()
    for i, batch in enumerate(train_loader):

        train_count += 1
        
#         texts, text_lengths, mels, gate_padded, mel_lengths, max_len = batch
#         texts, text_lengths, mels, gate_padded, mel_lengths = texts.to(device), text_lengths.to(device), mels.to(device), gate_padded.to(device), mel_lengths.to(device)

        torch.cuda.synchronize()
        model.zero_grad()
        x, y, num_items = batch_to_gpu(batch)
        outputs = model(x)
#         mel_outputs, mel_outputs_postnet, gate_outputs, alignments = outputs
#         targets = (mels, gate_padded)
        loss = criterion(outputs, y)
        reduced_loss = loss.item()
        if np.isnan(reduced_loss):
            raise Exception("loss is NaN")
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip_thresh)

        optimizer.step()
        model.zero_grad()
        mean_loss += loss.item()
        if (i) % 10 == 0:
            print(f'Epoch: {epoch+1}, Iteration: {i}, Loss: {loss.item()}')
        torch.cuda.synchronize()
    
    torch.cuda.synchronize()
    epoch_end_time = time.perf_counter()
    epoch_time = epoch_end_time - epoch_start_time
    mean_loss = mean_loss / train_count
    print(f'Epoch {epoch + 1} completed in {epoch_time:.2f} seconds, mean loss: {mean_loss}')
    
    if (epoch + 1) % 10 == 0:
        checkpoint_path = os.path.join('./processed_check_points/',f'checkpoint_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': mean_loss,
        }, checkpoint_path)
        print(f'Checkpoint saved at {checkpoint_path}')
# Out:
# 0.5820023287087679
# load epoch: 509
# Epoch: 511, Iteration: 0, Loss: 0.5504879951477051
# Epoch: 511, Iteration: 10, Loss: 0.5578972101211548
# Epoch 511 completed in 617.19 seconds, mean loss: 0.5865850895643234
# Epoch: 512, Iteration: 0, Loss: 0.5740936994552612
# Epoch: 512, Iteration: 10, Loss: 0.6150566339492798
# Epoch 512 completed in 591.18 seconds, mean loss: 0.5811640545725822
# Epoch: 513, Iteration: 0, Loss: 0.44456416368484497
# Epoch: 513, Iteration: 10, Loss: 0.6107544898986816
# Epoch 513 completed in 596.91 seconds, mean loss: 0.5760368220508099
# Epoch: 514, Iteration: 0, Loss: 0.6168411374092102
# Epoch: 514, Iteration: 10, Loss: 0.5262153744697571
# Epoch 514 completed in 544.29 seconds, mean loss: 0.5691762007772923
# Epoch: 515, Iteration: 0, Loss: 0.5928060412406921
# Epoch: 515, Iteration: 10, Loss: 0.486288845539093
# Epoch 515 completed in 512.06 seconds, mean loss: 0.597439356148243
# Epoch: 516, Iteration: 0, Loss: 0.5373785495758057
# Epoch: 516, Iteration: 10, Loss: 0.5938560962677002
# Epoch 516 completed in 511.24 seconds, mean loss: 0.5876063369214535
# Epoch: 517, Iteration: 0, Loss: 0.5764597058296204
# Epoch: 517, Iteration: 10, Loss: 0.5214024186134338
# Epoch 517 completed in 475.44 seconds, mean loss: 0.5933046843856573
# Epoch: 518, Iteration: 0, Loss: 0.43654385209083557
# Epoch: 518, Iteration: 10, Loss: 0.5556856989860535
# Epoch 518 completed in 470.28 seconds, mean loss: 0.5874047931283712
# Epoch: 519, Iteration: 0, Loss: 0.6058575510978699
# Epoch: 519, Iteration: 10, Loss: 0.4615391492843628
# Epoch 519 completed in 479.69 seconds, mean loss: 0.5684511065483093
# Epoch: 520, Iteration: 0, Loss: 0.5282927751541138
# Epoch: 520, Iteration: 10, Loss: 0.5839369297027588
# Epoch 520 completed in 492.54 seconds, mean loss: 0.5661152470856905
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_520.pt
# Epoch: 521, Iteration: 0, Loss: 0.6114731431007385
# Epoch: 521, Iteration: 10, Loss: 0.5447306632995605
# Epoch 521 completed in 484.16 seconds, mean loss: 0.5624604430049658
# Epoch: 522, Iteration: 0, Loss: 0.5048692226409912
# Epoch: 522, Iteration: 10, Loss: 0.5920512676239014
# Epoch 522 completed in 485.28 seconds, mean loss: 0.5676289387047291
# Epoch: 523, Iteration: 0, Loss: 0.5253022313117981
# Epoch: 523, Iteration: 10, Loss: 0.6220000386238098
# Epoch 523 completed in 479.24 seconds, mean loss: 0.5733294747769833
# Epoch: 524, Iteration: 0, Loss: 0.5258276462554932
# Epoch: 524, Iteration: 10, Loss: 0.6428973078727722
# Epoch 524 completed in 481.59 seconds, mean loss: 0.5928883422166109
# Epoch: 525, Iteration: 0, Loss: 0.525803804397583
# Epoch: 525, Iteration: 10, Loss: 0.5031862258911133
# Epoch 525 completed in 497.83 seconds, mean loss: 0.5725140944123268
# Epoch: 526, Iteration: 0, Loss: 0.5558263659477234
# Epoch: 526, Iteration: 10, Loss: 0.684772253036499
# Epoch 526 completed in 475.18 seconds, mean loss: 0.5755707863718271
# Epoch: 527, Iteration: 0, Loss: 0.5594004392623901
# Epoch: 527, Iteration: 10, Loss: 0.6091748476028442
# Epoch 527 completed in 502.86 seconds, mean loss: 0.5783529970794916
# Epoch: 528, Iteration: 0, Loss: 0.5340815186500549
# Epoch: 528, Iteration: 10, Loss: 0.6864194869995117
# Epoch 528 completed in 476.03 seconds, mean loss: 0.5965905599296093
# Epoch: 529, Iteration: 0, Loss: 0.6007188558578491
# Epoch: 529, Iteration: 10, Loss: 0.4445250630378723
# Epoch 529 completed in 491.74 seconds, mean loss: 0.5533419623970985
# Epoch: 530, Iteration: 0, Loss: 0.5106346607208252
# Epoch: 530, Iteration: 10, Loss: 0.5889658331871033
# Epoch 530 completed in 479.37 seconds, mean loss: 0.5569275431334972
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_530.pt
# Epoch: 531, Iteration: 0, Loss: 0.5869693160057068
# Epoch: 531, Iteration: 10, Loss: 0.5900806784629822
# Epoch 531 completed in 476.25 seconds, mean loss: 0.5832140389829874
# Epoch: 532, Iteration: 0, Loss: 0.5174132585525513
# Epoch: 532, Iteration: 10, Loss: 0.611121654510498
# Epoch 532 completed in 546.19 seconds, mean loss: 0.5790566634386778
# Epoch: 533, Iteration: 0, Loss: 0.54585862159729
# Epoch: 533, Iteration: 10, Loss: 0.6278300285339355
# Epoch 533 completed in 561.18 seconds, mean loss: 0.5619517974555492
# Epoch: 534, Iteration: 0, Loss: 0.6153954267501831
# Epoch: 534, Iteration: 10, Loss: 0.5210984945297241
# Epoch 534 completed in 464.11 seconds, mean loss: 0.5826113484799862
# Epoch: 535, Iteration: 0, Loss: 0.6404149532318115
# Epoch: 535, Iteration: 10, Loss: 0.516380786895752
# Epoch 535 completed in 494.60 seconds, mean loss: 0.5532518438994884
# Epoch: 536, Iteration: 0, Loss: 0.5311314463615417
# Epoch: 536, Iteration: 10, Loss: 0.6645057201385498
# Epoch 536 completed in 479.73 seconds, mean loss: 0.5623532086610794
# Epoch: 537, Iteration: 0, Loss: 0.5534976124763489
# Epoch: 537, Iteration: 10, Loss: 0.6032001972198486
# Epoch 537 completed in 502.44 seconds, mean loss: 0.5606567729264498
# Epoch: 538, Iteration: 0, Loss: 0.6489043831825256
# Epoch: 538, Iteration: 10, Loss: 0.6660585403442383
# Epoch 538 completed in 500.56 seconds, mean loss: 0.5915496703237295
# Epoch: 539, Iteration: 0, Loss: 0.5274536609649658
# Epoch: 539, Iteration: 10, Loss: 0.5675973892211914
# Epoch 539 completed in 508.30 seconds, mean loss: 0.5591286141425371
# Epoch: 540, Iteration: 0, Loss: 0.5624077320098877
# Epoch: 540, Iteration: 10, Loss: 0.5435996651649475
# Epoch 540 completed in 471.40 seconds, mean loss: 0.5614090971648693
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_540.pt
# Epoch: 541, Iteration: 0, Loss: 0.6244825124740601
# Epoch: 541, Iteration: 10, Loss: 0.5570216178894043
# Epoch 541 completed in 493.17 seconds, mean loss: 0.5723570212721825
# Epoch: 542, Iteration: 0, Loss: 0.5871068835258484
# Epoch: 542, Iteration: 10, Loss: 0.5926379561424255
# Epoch 542 completed in 473.92 seconds, mean loss: 0.5729764103889465
# Epoch: 543, Iteration: 0, Loss: 0.6523420214653015
# Epoch: 543, Iteration: 10, Loss: 0.6124892830848694
# Epoch 543 completed in 482.76 seconds, mean loss: 0.5621058065444231
# Epoch: 544, Iteration: 0, Loss: 0.4889267385005951
# Epoch: 544, Iteration: 10, Loss: 0.5528705716133118
# Epoch 544 completed in 489.36 seconds, mean loss: 0.5565195679664612
# Epoch: 545, Iteration: 0, Loss: 0.45949992537498474
# Epoch: 545, Iteration: 10, Loss: 0.5694276690483093
# Epoch 545 completed in 492.81 seconds, mean loss: 0.557394215837121
# Epoch: 546, Iteration: 0, Loss: 0.6072072386741638
# Epoch: 546, Iteration: 10, Loss: 0.5412577390670776
# Epoch 546 completed in 473.42 seconds, mean loss: 0.5774593520909548
# Epoch: 547, Iteration: 0, Loss: 0.5354560017585754
# Epoch: 547, Iteration: 10, Loss: 0.5205129981040955
# Epoch 547 completed in 470.30 seconds, mean loss: 0.5539343096315861
# Epoch: 548, Iteration: 0, Loss: 0.5096128582954407
# Epoch: 548, Iteration: 10, Loss: 0.5139724016189575
# Epoch 548 completed in 481.61 seconds, mean loss: 0.5487727224826813
# Epoch: 549, Iteration: 0, Loss: 0.5494122505187988
# Epoch: 549, Iteration: 10, Loss: 0.5642409324645996
# Epoch 549 completed in 469.57 seconds, mean loss: 0.5499261133372784
# Epoch: 550, Iteration: 0, Loss: 0.436256468296051
# Epoch: 550, Iteration: 10, Loss: 0.5009595155715942
# Epoch 550 completed in 464.70 seconds, mean loss: 0.5462386105209589
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_550.pt
# Epoch: 551, Iteration: 0, Loss: 0.572777509689331
# Epoch: 551, Iteration: 10, Loss: 0.5880526304244995
# Epoch 551 completed in 474.35 seconds, mean loss: 0.5434879567474127
# Epoch: 552, Iteration: 0, Loss: 0.5974734425544739
# Epoch: 552, Iteration: 10, Loss: 0.5527875423431396
# Epoch 552 completed in 495.90 seconds, mean loss: 0.5503227859735489
# Epoch: 553, Iteration: 0, Loss: 0.5532338619232178
# Epoch: 553, Iteration: 10, Loss: 0.4328678250312805
# Epoch 553 completed in 486.98 seconds, mean loss: 0.560068279504776
# Epoch: 554, Iteration: 0, Loss: 0.4136922359466553
# Epoch: 554, Iteration: 10, Loss: 0.4681651294231415
# Epoch 554 completed in 473.96 seconds, mean loss: 0.5416814498603344
# Epoch: 555, Iteration: 0, Loss: 0.48225072026252747
# Epoch: 555, Iteration: 10, Loss: 0.6144593954086304
# Epoch 555 completed in 459.61 seconds, mean loss: 0.5670987945050001
# Epoch: 556, Iteration: 0, Loss: 0.5392462015151978
# Epoch: 556, Iteration: 10, Loss: 0.5268180966377258
# Epoch 556 completed in 486.04 seconds, mean loss: 0.5569553915411234
# Epoch: 557, Iteration: 0, Loss: 0.6715895533561707
# Epoch: 557, Iteration: 10, Loss: 0.5061331391334534
# Epoch 557 completed in 471.43 seconds, mean loss: 0.5758199375122786
# Epoch: 558, Iteration: 0, Loss: 0.40717124938964844
# Epoch: 558, Iteration: 10, Loss: 0.514044463634491
# Epoch 558 completed in 485.09 seconds, mean loss: 0.5424925852566957
# Epoch: 559, Iteration: 0, Loss: 0.569169282913208
# Epoch: 559, Iteration: 10, Loss: 0.42247214913368225
# Epoch 559 completed in 489.75 seconds, mean loss: 0.5340423937886953
# Epoch: 560, Iteration: 0, Loss: 0.5139038562774658
# Epoch: 560, Iteration: 10, Loss: 0.5394854545593262
# Epoch 560 completed in 484.90 seconds, mean loss: 0.5464769341051579
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_560.pt
# Epoch: 561, Iteration: 0, Loss: 0.5381435751914978
# Epoch: 561, Iteration: 10, Loss: 0.48981067538261414
# Epoch 561 completed in 488.23 seconds, mean loss: 0.5432889275252819
# Epoch: 562, Iteration: 0, Loss: 0.48971518874168396
# Epoch: 562, Iteration: 10, Loss: 0.5839820504188538
# Epoch 562 completed in 483.19 seconds, mean loss: 0.5575322117656469
# Epoch: 563, Iteration: 0, Loss: 0.497691810131073
# Epoch: 563, Iteration: 10, Loss: 0.5111607313156128
# Epoch 563 completed in 481.06 seconds, mean loss: 0.5389672890305519
# Epoch: 564, Iteration: 0, Loss: 0.5648242235183716
# Epoch: 564, Iteration: 10, Loss: 0.6184264421463013
# Epoch 564 completed in 473.79 seconds, mean loss: 0.5585773829370737
# Epoch: 565, Iteration: 0, Loss: 0.4497714936733246
# Epoch: 565, Iteration: 10, Loss: 0.48674529790878296
# Epoch 565 completed in 485.83 seconds, mean loss: 0.5221740230917931
# Epoch: 566, Iteration: 0, Loss: 0.5635051727294922
# Epoch: 566, Iteration: 10, Loss: 0.6033482551574707
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 31
#      29     torch.cuda.synchronize()
#      30     epoch_start_time = time.perf_counter()
# ---> 31     for i, batch in enumerate(train_loader):
#      33         train_count += 1
#      35 #         texts, text_lengths, mels, gate_padded, mel_lengths, max_len = batch
#      36 #         texts, text_lengths, mels, gate_padded, mel_lengths = texts.to(device), text_lengths.to(device), mels.to(device), gate_padded.to(device), mel_lengths.to(device)
#
# File E:\study_software\anaconda\conda\lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File E:\study_software\anaconda\conda\lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File E:\study_software\anaconda\conda\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File E:\study_software\anaconda\conda\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[24], line 11, in Tacotron2Dataset.__getitem__(self, idx)
#       9 file_paths = self.file_list[idx]
#      10 phone_list, end_time = read_and_convert_phonemes(file_paths['phonetic_file'])
# ---> 11 mel_spectrogram = compute_mel_spectrogram(load_audio_from_path(file_paths['audio_file'][0:int(end_time)]))
#      13 phone_tensor = torch.tensor(phone_list, dtype=torch.int).clone().detach()
#      14 mel_tensor = mel_spectrogram.float()
#
# Cell In[15], line 6, in compute_mel_spectrogram(audio_data, sr, n_fft, hop_length, n_mels)
#       5 def compute_mel_spectrogram(audio_data, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
# ----> 6     stft = layers.TacotronSTFT(sampling_rate=16000)
#       8     audio_norm = audio_data / max_wav_value
#       9     audio_norm = audio_norm.unsqueeze(0)
#
# File D:\program\MscProj\./DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2\tacotron2_common\layers.py:75, in TacotronSTFT.__init__(self, filter_length, hop_length, win_length, n_mel_channels, sampling_rate, mel_fmin, mel_fmax)
#      73 self.n_mel_channels = n_mel_channels
#      74 self.sampling_rate = sampling_rate
# ---> 75 self.stft_fn = STFT(filter_length, hop_length, win_length)
#      76 mel_basis = librosa_mel_fn(
#      77     sr=sampling_rate,
#      78     n_fft=filter_length,
#    (...)
#      81     fmax=mel_fmax
#      82 )
#      84 mel_basis = torch.from_numpy(mel_basis).float()
#
# File D:\program\MscProj\./DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2\tacotron2_common\stft.py:61, in STFT.__init__(self, filter_length, hop_length, win_length, window)
#      56 fourier_basis = np.vstack([np.real(fourier_basis[:cutoff, :]),
#      57                            np.imag(fourier_basis[:cutoff, :])])
#      59 forward_basis = torch.FloatTensor(fourier_basis[:, None, :])
#      60 inverse_basis = torch.FloatTensor(
# ---> 61     np.linalg.pinv(scale * fourier_basis).T[:, None, :].astype(np.float32))
#      63 if window is not None:
#      64     assert(filter_length >= win_length)
#
# File <__array_function__ internals>:200, in pinv(*args, **kwargs)
#
# File E:\study_software\anaconda\conda\lib\site-packages\numpy\linalg\linalg.py:1983, in pinv(a, rcond, hermitian)
#    1981     return wrap(res)
#    1982 a = a.conjugate()
# -> 1983 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1985 # discard small singular values
#    1986 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File E:\study_software\anaconda\conda\lib\site-packages\numpy\linalg\linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
model = Tacotron2(**hparams).to(device)
checkpoint = torch.load(os.path.join('./processed_check_points/','checkpoint_epoch_560.pt'))

load_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['model_state_dict'])
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
phoneme_sequence,end_time = read_and_convert_phonemes(tacotron_file_list[10]['phonetic_file'])
print(phoneme_sequence)
length = [len(phoneme_sequence)]
inputs = torch.tensor(phoneme_sequence, dtype=torch.int).unsqueeze(0).to(device)
input_lengths = torch.tensor(length, dtype=torch.int).to(device)
print(inputs.shape)
print(input_lengths)
model.eval()

with torch.no_grad():
    mel_outputs, mel_lengths, alignments = model.infer(inputs, input_lengths)

print("Mel Outputs Postnet:", mel_outputs)
print("Mel Lengths:", mel_lengths)
print("Alignments:", alignments)
print(mel_outputs.shape)
play_audio = play_mel_audio(mel_outputs[0])
play_audio
# Out:
# [38, 28, 17, 22, 5, 22, 38, 10, 6, 38, 31, 34, 2, 21, 3, 38, 4, 38, 11, 5, 23, 17, 38, 20, 21, 38, 31, 36, 17, 23, 15, 38, 31, 17, 38, 5, 23, 38, 31, 6, 13, 28, 18, 21, 18, 38, 39]
# torch.Size([1, 47])
# tensor([47], device='cuda:0', dtype=torch.int32)
# Mel Outputs Postnet: tensor([[[-8.5186, -8.2329, -8.2975,  ..., -7.3295, -6.6112, -4.4273],
#          [-9.2644, -8.9011, -8.9370,  ..., -7.6295, -6.6912, -4.0440],
#          [-9.2599, -8.9606, -9.0156,  ..., -7.7698, -6.8009, -4.2006],
#          ...,
#          [-9.9903, -9.8869, -9.7980,  ..., -8.9185, -7.8695, -4.9556],
#          [-9.9586, -9.7991, -9.7109,  ..., -8.9210, -7.7923, -4.7890],
#          [-9.8882, -9.7817, -9.7344,  ..., -9.0925, -8.0369, -5.2163]]],
#        device='cuda:0')
# Mel Lengths: tensor([221], device='cuda:0', dtype=torch.int32)
# Alignments: tensor([[[1.2234e-01, 6.8358e-02, 2.1043e-02,  ..., 1.1077e-05,
#           6.1144e-06, 2.9901e-05],
#          [1.9205e-01, 1.4145e-01, 1.4216e-03,  ..., 1.7291e-05,
#           4.1902e-06, 3.4951e-06],
#          [2.5186e-01, 1.3517e-01, 1.1289e-03,  ..., 2.5481e-05,
#           1.1445e-05, 1.0521e-05],
#          ...,
#          [5.9227e-02, 1.1930e-02, 2.2093e-03,  ..., 3.4075e-02,
#           8.8881e-02, 5.5213e-01],
#          [2.9609e-02, 6.8706e-03, 1.5679e-03,  ..., 2.2527e-02,
#           6.4649e-02, 7.1623e-01],
#          [2.7051e-02, 6.2325e-03, 1.7354e-03,  ..., 1.8747e-02,
#           9.0394e-02, 6.9100e-01]]], device='cuda:0')
# torch.Size([1, 80, 222])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
raw_audio = load_audio_from_path(tacotron_file_list[10]['audio_file'])
print(raw_audio.shape)
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
# torch.Size([57344])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
