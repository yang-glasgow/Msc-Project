# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import librosa
import torchaudio
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys

from tqdm.auto import tqdm
from IPython.display import Audio

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA version: {torch.version.cuda}")
print(f"CUDNN version: {torch.backends.cudnn.version()}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# cuda
# PyTorch version: 2.3.1
# CUDA version: 12.1
# CUDNN version: 8907
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
file_path = './TIMIT/'
data_path = './TIMIT/data'

train_data = pd.read_csv(os.path.join(file_path, 'train_data.csv'))
test_data = pd.read_csv(os.path.join(file_path, 'test_data.csv'))
df = pd.concat([train_data, test_data])

# %%
female_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str and row['speaker_id'].startswith('F'):
        if filename.split('.')[0] in ['SA1','SA2']:
            continue
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in female_files:
            female_files[filename]={}
        
        if filename in female_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                female_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                female_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                female_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(audio_files))
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break
# Out:
# 6300
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}

# %%
female_files = {}
for index, row in df.iterrows():
    filename = row['filename']
    if type(filename) == str and row['speaker_id'].startswith('F'):
        if filename.split('.')[0] in ['SA1','SA2']:
            continue
        filename = row['speaker_id'] + ' ' + filename.split('.')[0]
        if filename not in female_files:
            female_files[filename]={}
        
        if filename in female_files:
            if row['is_audio'] is True and row['is_converted_audio'] == True:
                female_files[filename]['audio_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_word_file'] is True:
                female_files[filename]['word_file'] = os.path.join(data_path, row['path_from_data_dir'])
            elif row['is_phonetic_file'] is True:
                female_files[filename]['phonetic_file'] = os.path.join(data_path, row['path_from_data_dir'])

# %%
print(len(female_files))
# Out:
# 1536

# %%
tacotron_file_list = []
for key,files in female_files.items():
    if len(files) == 3:
        tacotron_file_list.append(files)
print(len(tacotron_file_list))
# Out:
# 792

# %%
# TimitBet 61 phoneme mapping to 39 phonemes
# by Lee, K.-F., & Hon, H.-W. (1989). Speaker-independent phone recognition using hidden Markov models. IEEE Transactions on Acoustics, Speech, and Signal Processing, 37(11), 1641–1648. doi:10.1109/29.46546 
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

# %%
from scipy.io.wavfile import read
y1, sr1 = librosa.load('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav', sr=16000)
sr2, y2 = read('./TIMIT/data/TRAIN/DR1/FDAW0/SA1.WAV.wav')
print(f'Shape of audio sequence: {y2.shape}')
print(f'sample rate: {sr2}')
if np.array_equal(y1, y2):
    print('y1=y2')
else:
    print('y1!=y2')
# Out:
# 音频时间序列的形状: (53556,)
# 采样率: 16000
# y1!=y2

# %%
# def compute_mel_spectrogram(y, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
#     mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
#     log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
#     return log_mel_spectrogram

# %%
# mel_y1 = compute_mel_spectrogram(y1[0:1000])
# print(mel_y1[0])

# %%
# !git clone https://github.com/NVIDIA/DeepLearningExamples.git

# %%
waveglow_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/'
sys.path.append(waveglow_path)
tacotron2_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/'
sys.path.append(tacotron2_path)

# %%
from denoiser import Denoiser
from model import WaveGlow
import data_function
import loss_function
from loss_function import WaveGlowLoss
import importlib.util
entrypoints_path = './DeepLearningExamples/PyTorch/SpeechSynthesis/Tacotron2/waveglow/entrypoints.py'

spec = importlib.util.spec_from_file_location("entrypoints", entrypoints_path)
entrypoints = importlib.util.module_from_spec(spec)
sys.modules["entrypoints"] = entrypoints
spec.loader.exec_module(entrypoints)

from entrypoints import nvidia_waveglow

# %%
from scipy.io.wavfile import read
import tacotron2_common.layers as layers
max_wav_value = 32768.0

def compute_mel_spectrogram(audio_data, sr=16000, n_fft=1024, hop_length=256, n_mels=80):
    stft = layers.TacotronSTFT(sampling_rate=16000)
    
    audio_norm = audio_data / max_wav_value
    audio_norm = audio_norm.unsqueeze(0)
    audio_norm = torch.autograd.Variable(audio_norm, requires_grad=False)
    melspec = stft.mel_spectrogram(audio_norm)
    melspec = torch.squeeze(melspec, 0)

    return melspec

def load_audio_from_path(path):
    sampling_rate, data = read(path)
    audio_data = torch.FloatTensor(data.astype(np.float32))

    return audio_data

def compute_mel_from_path(path):
    return compute_mel_spectrogram(load_audio_from_path(path))

# %%
from torch.utils.data import DataLoader

def load_mel_audio(file_path, sr=16000, n_mels=80, n_fft=1024, hop_length=256):

    audio = load_audio_from_path(file_path)
    
    melspec = compute_mel_spectrogram(audio)
    
    return melspec, audio

class MelDataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        mel_spectrogram, audio = load_mel_audio(file_path)
        return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)

file_list = []
for (key,value) in female_files.items():
    file_list.append(value['audio_file'])

dataset = MelDataset(file_list)
train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
dataset[0]
# Out:
# C:\Users\YANG\AppData\Local\Temp\ipykernel_7096\556344903.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(mel_spectrogram, dtype=torch.float32).to(device), torch.tensor(audio, dtype=torch.float32).to(device)
# (tensor([[ -8.4898,  -8.4369,  -9.0065,  ...,  -6.8391,  -7.0954,  -7.3317],
#          [ -9.8049,  -9.1275,  -9.2912,  ...,  -6.9650,  -6.6273,  -6.6464],
#          [ -9.1401,  -9.1792,  -9.6098,  ...,  -7.8798,  -6.9461,  -6.9621],
#          ...,
#          [ -9.7159, -10.0164, -10.0679,  ...,  -9.3277,  -9.2204,  -9.2737],
#          [ -9.5567,  -9.7603,  -9.9210,  ...,  -9.1527,  -9.1147,  -9.2802],
#          [ -9.4876,  -9.6483,  -9.7763,  ...,  -9.7336,  -9.6742,  -9.6836]],
#         device='cuda:0'),
#  tensor([14., -7., -1.,  ..., -4., -4., -1.], device='cuda:0'))

# %%
n_mel_channels = 80
n_flows = 12
n_group = 8
n_early_every = 4
n_early_size = 2
WN_config = {
    "n_layers": 8,
    "n_channels": 512,
    "kernel_size": 3
}

# waveglow = WaveGlow(n_mel_channels, n_flows, n_group, n_early_every, n_early_size, WN_config)
# waveglow = waveglow.cuda()

waveglow =  nvidia_waveglow(pretrained=True, model_math='fp32')
waveglow = waveglow.cuda()
# Out:
# E:\study_software\anaconda\conda\lib\site-packages\torch\nn\utils\weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
from denoiser import Denoiser
tem_mal = compute_mel_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav').to(device)

with torch.no_grad():
    audio = waveglow.infer(tem_mal.unsqueeze(0).to(device), sigma=0.666)

denoiser = Denoiser(waveglow)
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
audio_numpy = audio_denoised.cpu().numpy()

Audio(audio_numpy, rate=18000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
raw_audio = load_audio_from_path('./TIMIT/data/TRAIN/DR1/FCJF0/SA1.WAV.wav')
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# TimitBet 61 phoneme mapping to 39 phonemes
# by Lee, K.-F., & Hon, H.-W. (1989). Speaker-independent phone recognition using hidden Markov models. IEEE Transactions on Acoustics, Speech, and Signal Processing, 37(11), 1641–1648. doi:10.1109/29.46546 
pho61_to_pho39 = {
    'iy':'iy',  'ih':'ih',   'eh':'eh',  'ae':'ae',    'ix':'ih',  'ax':'ah',   'ah':'ah',  'uw':'uw',
    'ux':'uw',  'uh':'uh',   'ao':'aa',  'aa':'aa',    'ey':'ey',  'ay':'ay',   'oy':'oy',  'aw':'aw',
    'ow':'ow',  'l':'l',     'el':'l',  'r':'r',      'y':'y',    'w':'w',     'er':'er',  'axr':'er',
    'm':'m',    'em':'m',     'n':'n',    'nx':'n',     'en':'n',  'ng':'ng',   'eng':'ng', 'ch':'ch',
    'jh':'jh',  'dh':'dh',   'b':'b',    'd':'d',      'dx':'dx',  'g':'g',     'p':'p',    't':'t',
    'k':'k',    'z':'z',     'zh':'sh',  'v':'v',      'f':'f',    'th':'th',   's':'s',    'sh':'sh',
    'hh':'hh',  'hv':'hh',   'pcl':'h#', 'tcl':'h#', 'kcl':'h#', 'qcl':'h#','bcl':'h#','dcl':'h#',
    'gcl':'h#','h#':'h#',  '#h':'h#',  'pau':'h#', 'epi': 'h#','nx':'n',   'ax-h':'ah','q':'h#' 
}
pho39_to_index = {
    'aa': 1, 'ae': 2, 'ah': 3, 'aw': 4, 'ay': 5, 'eh': 6, 'er': 7, 'ey': 8, 
    'dh': 9, 'dx': 10, 'b': 11, 'd': 12, 'ch': 13, 'f': 14, 'g': 15, 'z': 16, 
    'hh': 17, 'ih': 18, 'iy': 19, 'jh': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 
    'ng': 25, 'ow': 26, 'oy': 27, 'p': 28, 'r': 29, 's': 30, 'sh': 31, 't': 32, 
    'th': 33, 'uh': 34, 'uw': 35, 'v': 36, 'w': 37, 'y': 38, 'h#': 39
}

def play_mel_audio(mel_spectrogram):
    with torch.no_grad():
        audio = waveglow.infer(mel_spectrogram.unsqueeze(0).to(device), sigma=1)
    
    denoiser = Denoiser(waveglow)
    audio_denoised = denoiser(audio, strength=0.01)[:, 0]
    audio_numpy = audio_denoised.cpu().numpy()
    
    return Audio(audio_numpy, rate=18000)

# %%
def read_and_convert_phonemes(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    end_time = 0
    
    phoneme_indices = []
    
    for line in lines:
        parts = line.strip().split()
        
        if len(parts) != 3:
            continue
        end_time = parts[1]
        phoneme = parts[2]

        if phoneme in pho61_to_pho39:
            pho39 = pho61_to_pho39[phoneme]
            if pho39 in pho39_to_index:
                index = pho39_to_index[pho39]-1
                phoneme_indices.append(index)
    phoneme_indices.append(39)
    
    return phoneme_indices,end_time

# %%
for key,value in audio_files.items():
    print ('key: ',key,'value: ',value)
    break

tacotron_file_list = []
for key,files in female_files.items():
    if len(files) == 3:
        tacotron_file_list.append(files)
print(len(tacotron_file_list))
# Out:
# key:  MMDM0 SI681 value:  {'audio_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WAV.wav', 'phonetic_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.PHN', 'word_file': './TIMIT/data\\TRAIN/DR4/MMDM0/SI681.WRD'}
# 792

# %%
class Tacotron2Dataset(torch.utils.data.Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_paths = self.file_list[idx]
        phone_list, end_time = read_and_convert_phonemes(file_paths['phonetic_file'])
        mel_spectrogram = compute_mel_spectrogram(load_audio_from_path(file_paths['audio_file'][0:int(end_time)]))
        
        phone_tensor = torch.tensor(phone_list, dtype=torch.int).clone().detach()
        mel_tensor = mel_spectrogram.float()
        
        return phone_tensor, mel_tensor, len(phone_list)

# %%
tacotron_dataset = Tacotron2Dataset(tacotron_file_list)
tacotron_dataset[0][1].shape
# Out:
# torch.Size([80, 180])

# %%
from tacotron2.model import Tacotron2
from tacotron2.loss_function import Tacotron2Loss
hparams = {
    'n_mel_channels': 80,
    'n_symbols': 40, 
    'symbols_embedding_dim': 512,
    'encoder_kernel_size': 5,
    'encoder_n_convolutions': 3,
    'encoder_embedding_dim': 512,
    'attention_rnn_dim': 1024,
    'attention_dim': 128,
    'attention_location_n_filters': 32,
    'attention_location_kernel_size': 31,
    'n_frames_per_step': 1,
    'decoder_rnn_dim': 1024,
    'prenet_dim': 256,
    'max_decoder_steps': 1000,
    'gate_threshold': 0.5,
    'p_attention_dropout': 0.1,
    'p_decoder_dropout': 0.1,
    'postnet_embedding_dim': 512,
    'postnet_kernel_size': 5,
    'postnet_n_convolutions': 5,
    'decoder_no_early_stopping': False,
    'mask_padding': False
}
model = Tacotron2(**hparams).to(device)

# %%
# !pip install inflect

# %%
import data_functions
import time
import loss_functions

# torch.autograd.set_detect_anomaly(True)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

model_name = 'Tacotron2'
criterion = loss_functions.get_loss_function(model_name)
collate_fn = data_functions.get_collate_function(model_name)
train_loader = DataLoader(tacotron_dataset, num_workers=0, shuffle=True, batch_size=64, pin_memory=False, drop_last=False, collate_fn=collate_fn)
batch_to_gpu = data_functions.get_batch_to_gpu(model_name)

epochs = 300  
grad_clip_thresh = 1.0  

model.train()

for epoch in range(epochs):
    mean_loss = 0
    train_count = 0
    torch.cuda.synchronize()
    epoch_start_time = time.perf_counter()
    for i, batch in enumerate(train_loader):

        train_count += 1
        
#         texts, text_lengths, mels, gate_padded, mel_lengths, max_len = batch
#         texts, text_lengths, mels, gate_padded, mel_lengths = texts.to(device), text_lengths.to(device), mels.to(device), gate_padded.to(device), mel_lengths.to(device)

        torch.cuda.synchronize()
        model.zero_grad()
        x, y, num_items = batch_to_gpu(batch)
        outputs = model(x)
#         mel_outputs, mel_outputs_postnet, gate_outputs, alignments = outputs
#         targets = (mels, gate_padded)
        loss = criterion(outputs, y)
        reduced_loss = loss.item()
        if np.isnan(reduced_loss):
            raise Exception("loss is NaN")
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip_thresh)

        optimizer.step()
        model.zero_grad()
        mean_loss += loss.item()
        if (i) % 10 == 0:
            print(f'Epoch: {epoch+1}, Iteration: {i}, Loss: {loss.item()}')
        torch.cuda.synchronize()
    
    torch.cuda.synchronize()
    epoch_end_time = time.perf_counter()
    epoch_time = epoch_end_time - epoch_start_time
    mean_loss = mean_loss / train_count
    print(f'Epoch {epoch + 1} completed in {epoch_time:.2f} seconds, mean loss: {mean_loss}')
    
    if (epoch + 1) % 10 == 0:
        checkpoint_path = os.path.join('./processed_check_points/',f'checkpoint_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': mean_loss,
        }, checkpoint_path)
        print(f'Checkpoint saved at {checkpoint_path}')
# Out:
# Epoch: 1, Iteration: 0, Loss: 53.68150329589844
# Epoch: 1, Iteration: 10, Loss: 6.814576148986816
# Epoch 1 completed in 395.31 seconds, mean loss: 15.290390418126034
# Epoch: 2, Iteration: 0, Loss: 5.209586143493652
# Epoch: 2, Iteration: 10, Loss: 4.2812418937683105
# Epoch 2 completed in 385.07 seconds, mean loss: 4.310731007502629
# Epoch: 3, Iteration: 0, Loss: 4.337457180023193
# Epoch: 3, Iteration: 10, Loss: 3.731165647506714
# Epoch 3 completed in 378.56 seconds, mean loss: 3.8585652021261363
# Epoch: 4, Iteration: 0, Loss: 3.6564056873321533
# Epoch: 4, Iteration: 10, Loss: 3.3033461570739746
# Epoch 4 completed in 378.89 seconds, mean loss: 3.6024158734541674
# Epoch: 5, Iteration: 0, Loss: 3.7113616466522217
# Epoch: 5, Iteration: 10, Loss: 3.5964531898498535
# Epoch 5 completed in 355.55 seconds, mean loss: 3.542256923822256
# Epoch: 6, Iteration: 0, Loss: 3.4647202491760254
# Epoch: 6, Iteration: 10, Loss: 3.7912051677703857
# Epoch 6 completed in 367.91 seconds, mean loss: 3.447118850854727
# Epoch: 7, Iteration: 0, Loss: 3.247758150100708
# Epoch: 7, Iteration: 10, Loss: 3.5654215812683105
# Epoch 7 completed in 372.20 seconds, mean loss: 3.337723731994629
# Epoch: 8, Iteration: 0, Loss: 3.425675630569458
# Epoch: 8, Iteration: 10, Loss: 3.207947254180908
# Epoch 8 completed in 370.19 seconds, mean loss: 3.170861922777616
# Epoch: 9, Iteration: 0, Loss: 2.9236185550689697
# Epoch: 9, Iteration: 10, Loss: 2.9223084449768066
# Epoch 9 completed in 356.89 seconds, mean loss: 3.11019752575801
# Epoch: 10, Iteration: 0, Loss: 2.8095929622650146
# Epoch: 10, Iteration: 10, Loss: 3.2256736755371094
# Epoch 10 completed in 383.49 seconds, mean loss: 3.0662598609924316
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_10.pt
# Epoch: 11, Iteration: 0, Loss: 3.0061886310577393
# Epoch: 11, Iteration: 10, Loss: 2.814683437347412
# Epoch 11 completed in 415.33 seconds, mean loss: 2.9073539880605845
# Epoch: 12, Iteration: 0, Loss: 2.4248147010803223
# Epoch: 12, Iteration: 10, Loss: 2.8751041889190674
# Epoch 12 completed in 386.73 seconds, mean loss: 2.7576008393214297
# Epoch: 13, Iteration: 0, Loss: 2.7620887756347656
# Epoch: 13, Iteration: 10, Loss: 2.608285903930664
# Epoch 13 completed in 392.45 seconds, mean loss: 2.665631807767428
# Epoch: 14, Iteration: 0, Loss: 2.5872912406921387
# Epoch: 14, Iteration: 10, Loss: 2.582595109939575
# Epoch 14 completed in 380.30 seconds, mean loss: 2.6029635025904727
# Epoch: 15, Iteration: 0, Loss: 2.5575015544891357
# Epoch: 15, Iteration: 10, Loss: 2.3424179553985596
# Epoch 15 completed in 375.30 seconds, mean loss: 2.5088018637437086
# Epoch: 16, Iteration: 0, Loss: 2.3331363201141357
# Epoch: 16, Iteration: 10, Loss: 2.267656087875366
# Epoch 16 completed in 373.81 seconds, mean loss: 2.469587124311007
# Epoch: 17, Iteration: 0, Loss: 2.447765350341797
# Epoch: 17, Iteration: 10, Loss: 2.338318347930908
# Epoch 17 completed in 366.48 seconds, mean loss: 2.4116470446953406
# Epoch: 18, Iteration: 0, Loss: 2.4980685710906982
# Epoch: 18, Iteration: 10, Loss: 2.5382556915283203
# Epoch 18 completed in 371.27 seconds, mean loss: 2.4216612118941088
# Epoch: 19, Iteration: 0, Loss: 2.492029905319214
# Epoch: 19, Iteration: 10, Loss: 2.209547758102417
# Epoch 19 completed in 378.99 seconds, mean loss: 2.3153223991394043
# Epoch: 20, Iteration: 0, Loss: 2.1293857097625732
# Epoch: 20, Iteration: 10, Loss: 2.2122802734375
# Epoch 20 completed in 376.83 seconds, mean loss: 2.2409351422236514
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_20.pt
# Epoch: 21, Iteration: 0, Loss: 2.327500104904175
# Epoch: 21, Iteration: 10, Loss: 2.1090707778930664
# Epoch 21 completed in 373.38 seconds, mean loss: 2.2606329184312086
# Epoch: 22, Iteration: 0, Loss: 2.115898847579956
# Epoch: 22, Iteration: 10, Loss: 2.1953248977661133
# Epoch 22 completed in 374.02 seconds, mean loss: 2.2103844239161563
# Epoch: 23, Iteration: 0, Loss: 2.0537352561950684
# Epoch: 23, Iteration: 10, Loss: 2.1030800342559814
# Epoch 23 completed in 377.66 seconds, mean loss: 2.1556834899462185
# Epoch: 24, Iteration: 0, Loss: 2.0415124893188477
# Epoch: 24, Iteration: 10, Loss: 2.078266143798828
# Epoch 24 completed in 378.64 seconds, mean loss: 2.118139101908757
# Epoch: 25, Iteration: 0, Loss: 2.100085735321045
# Epoch: 25, Iteration: 10, Loss: 2.052948474884033
# Epoch 25 completed in 371.08 seconds, mean loss: 2.130376494847811
# Epoch: 26, Iteration: 0, Loss: 2.070919990539551
# Epoch: 26, Iteration: 10, Loss: 1.7319397926330566
# Epoch 26 completed in 375.96 seconds, mean loss: 2.0734616426321177
# Epoch: 27, Iteration: 0, Loss: 1.7305316925048828
# Epoch: 27, Iteration: 10, Loss: 1.976611852645874
# Epoch 27 completed in 384.84 seconds, mean loss: 2.026462224813608
# Epoch: 28, Iteration: 0, Loss: 1.8286672830581665
# Epoch: 28, Iteration: 10, Loss: 2.0689804553985596
# Epoch 28 completed in 363.69 seconds, mean loss: 2.0143285256165724
# Epoch: 29, Iteration: 0, Loss: 1.9911420345306396
# Epoch: 29, Iteration: 10, Loss: 1.8390120267868042
# Epoch 29 completed in 379.63 seconds, mean loss: 1.9411778908509474
# Epoch: 30, Iteration: 0, Loss: 1.8662434816360474
# Epoch: 30, Iteration: 10, Loss: 1.7893829345703125
# Epoch 30 completed in 382.91 seconds, mean loss: 1.940259805092445
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_30.pt
# Epoch: 31, Iteration: 0, Loss: 1.9626121520996094
# Epoch: 31, Iteration: 10, Loss: 1.9120111465454102
# Epoch 31 completed in 379.77 seconds, mean loss: 1.93245137654818
# Epoch: 32, Iteration: 0, Loss: 1.8935333490371704
# Epoch: 32, Iteration: 10, Loss: 1.8293706178665161
# Epoch 32 completed in 378.28 seconds, mean loss: 1.8936936488518348
# Epoch: 33, Iteration: 0, Loss: 1.9209411144256592
# Epoch: 33, Iteration: 10, Loss: 1.798446774482727
# Epoch 33 completed in 370.12 seconds, mean loss: 1.8860508753703191
# Epoch: 34, Iteration: 0, Loss: 1.9432123899459839
# Epoch: 34, Iteration: 10, Loss: 1.7802067995071411
# Epoch 34 completed in 376.24 seconds, mean loss: 1.8857244619956384
# Epoch: 35, Iteration: 0, Loss: 1.866868019104004
# Epoch: 35, Iteration: 10, Loss: 1.827939510345459
# Epoch 35 completed in 370.55 seconds, mean loss: 1.7942859484599187
# Epoch: 36, Iteration: 0, Loss: 1.6467077732086182
# Epoch: 36, Iteration: 10, Loss: 1.9450775384902954
# Epoch 36 completed in 372.65 seconds, mean loss: 1.8012999662986169
# Epoch: 37, Iteration: 0, Loss: 1.779126524925232
# Epoch: 37, Iteration: 10, Loss: 1.7763547897338867
# Epoch 37 completed in 368.58 seconds, mean loss: 1.7547815121137178
# Epoch: 38, Iteration: 0, Loss: 1.891381025314331
# Epoch: 38, Iteration: 10, Loss: 1.8087204694747925
# Epoch 38 completed in 384.04 seconds, mean loss: 1.768626754100506
# Epoch: 39, Iteration: 0, Loss: 1.6772632598876953
# Epoch: 39, Iteration: 10, Loss: 1.6811789274215698
# Epoch 39 completed in 383.40 seconds, mean loss: 1.7228508729201097
# Epoch: 40, Iteration: 0, Loss: 1.8551526069641113
# Epoch: 40, Iteration: 10, Loss: 1.5927643775939941
# Epoch 40 completed in 393.91 seconds, mean loss: 1.7024557498785167
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_40.pt
# Epoch: 41, Iteration: 0, Loss: 1.652659296989441
# Epoch: 41, Iteration: 10, Loss: 1.6634559631347656
# Epoch 41 completed in 388.76 seconds, mean loss: 1.664860542003925
# Epoch: 42, Iteration: 0, Loss: 1.343548059463501
# Epoch: 42, Iteration: 10, Loss: 1.630613923072815
# Epoch 42 completed in 388.97 seconds, mean loss: 1.699954784833468
# Epoch: 43, Iteration: 0, Loss: 1.4418127536773682
# Epoch: 43, Iteration: 10, Loss: 1.7104098796844482
# Epoch 43 completed in 374.41 seconds, mean loss: 1.675395809687101
# Epoch: 44, Iteration: 0, Loss: 1.586653709411621
# Epoch: 44, Iteration: 10, Loss: 1.542458415031433
# Epoch 44 completed in 369.22 seconds, mean loss: 1.6207715914799616
# Epoch: 45, Iteration: 0, Loss: 1.6150094270706177
# Epoch: 45, Iteration: 10, Loss: 1.647396445274353
# Epoch 45 completed in 382.17 seconds, mean loss: 1.6342317691216102
# Epoch: 46, Iteration: 0, Loss: 1.6646273136138916
# Epoch: 46, Iteration: 10, Loss: 1.5877059698104858
# Epoch 46 completed in 377.97 seconds, mean loss: 1.5625960643474872
# Epoch: 47, Iteration: 0, Loss: 1.7114225625991821
# Epoch: 47, Iteration: 10, Loss: 1.5886563062667847
# Epoch 47 completed in 375.92 seconds, mean loss: 1.5641417870154748
# Epoch: 48, Iteration: 0, Loss: 1.5308398008346558
# Epoch: 48, Iteration: 10, Loss: 1.542238473892212
# Epoch 48 completed in 378.24 seconds, mean loss: 1.5059016209382277
# Epoch: 49, Iteration: 0, Loss: 1.6421617269515991
# Epoch: 49, Iteration: 10, Loss: 1.839029312133789
# Epoch 49 completed in 366.48 seconds, mean loss: 1.5368364224067101
# Epoch: 50, Iteration: 0, Loss: 1.693640112876892
# Epoch: 50, Iteration: 10, Loss: 1.4824929237365723
# Epoch 50 completed in 365.31 seconds, mean loss: 1.5041128121889555
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_50.pt
# Epoch: 51, Iteration: 0, Loss: 1.3734452724456787
# Epoch: 51, Iteration: 10, Loss: 1.549612283706665
# Epoch 51 completed in 371.34 seconds, mean loss: 1.4962516472889826
# Epoch: 52, Iteration: 0, Loss: 1.3347156047821045
# Epoch: 52, Iteration: 10, Loss: 1.3771593570709229
# Epoch 52 completed in 371.06 seconds, mean loss: 1.457406530013451
# Epoch: 53, Iteration: 0, Loss: 1.701601266860962
# Epoch: 53, Iteration: 10, Loss: 1.3944364786148071
# Epoch 53 completed in 368.98 seconds, mean loss: 1.4529179976536677
# Epoch: 54, Iteration: 0, Loss: 1.4751192331314087
# Epoch: 54, Iteration: 10, Loss: 1.3276723623275757
# Epoch 54 completed in 372.19 seconds, mean loss: 1.452099350782541
# Epoch: 55, Iteration: 0, Loss: 1.4574772119522095
# Epoch: 55, Iteration: 10, Loss: 1.2756868600845337
# Epoch 55 completed in 366.53 seconds, mean loss: 1.4511137283765352
# Epoch: 56, Iteration: 0, Loss: 1.2898597717285156
# Epoch: 56, Iteration: 10, Loss: 1.3276526927947998
# Epoch 56 completed in 381.93 seconds, mean loss: 1.36368662577409
# Epoch: 57, Iteration: 0, Loss: 1.389966607093811
# Epoch: 57, Iteration: 10, Loss: 1.5032192468643188
# Epoch 57 completed in 376.08 seconds, mean loss: 1.4494697222342858
# Epoch: 58, Iteration: 0, Loss: 1.1585326194763184
# Epoch: 58, Iteration: 10, Loss: 1.4758785963058472
# Epoch 58 completed in 375.73 seconds, mean loss: 1.4869558536089384
# Epoch: 59, Iteration: 0, Loss: 1.5487210750579834
# Epoch: 59, Iteration: 10, Loss: 1.3628228902816772
# Epoch 59 completed in 370.36 seconds, mean loss: 1.4418564759767973
# Epoch: 60, Iteration: 0, Loss: 1.6102018356323242
# Epoch: 60, Iteration: 10, Loss: 1.4596097469329834
# Epoch 60 completed in 367.51 seconds, mean loss: 1.383062170102046
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_60.pt
# Epoch: 61, Iteration: 0, Loss: 1.4068586826324463
# Epoch: 61, Iteration: 10, Loss: 1.2546957731246948
# Epoch 61 completed in 382.05 seconds, mean loss: 1.3696945997384877
# Epoch: 62, Iteration: 0, Loss: 1.4360017776489258
# Epoch: 62, Iteration: 10, Loss: 1.3489243984222412
# Epoch 62 completed in 373.50 seconds, mean loss: 1.3386298326345591
# Epoch: 63, Iteration: 0, Loss: 1.242133617401123
# Epoch: 63, Iteration: 10, Loss: 1.2678661346435547
# Epoch 63 completed in 374.62 seconds, mean loss: 1.3421902564855723
# Epoch: 64, Iteration: 0, Loss: 1.0435885190963745
# Epoch: 64, Iteration: 10, Loss: 1.2718393802642822
# Epoch 64 completed in 371.87 seconds, mean loss: 1.3316128529035127
# Epoch: 65, Iteration: 0, Loss: 1.1303269863128662
# Epoch: 65, Iteration: 10, Loss: 1.2543985843658447
# Epoch 65 completed in 378.90 seconds, mean loss: 1.3026892772087684
# Epoch: 66, Iteration: 0, Loss: 1.4068065881729126
# Epoch: 66, Iteration: 10, Loss: 1.0862562656402588
# Epoch 66 completed in 359.88 seconds, mean loss: 1.3402327390817494
# Epoch: 67, Iteration: 0, Loss: 1.0378056764602661
# Epoch: 67, Iteration: 10, Loss: 1.2220083475112915
# Epoch 67 completed in 376.95 seconds, mean loss: 1.2583289604920607
# Epoch: 68, Iteration: 0, Loss: 1.3594787120819092
# Epoch: 68, Iteration: 10, Loss: 1.2112133502960205
# Epoch 68 completed in 372.95 seconds, mean loss: 1.3145487858698919
# Epoch: 69, Iteration: 0, Loss: 1.1247538328170776
# Epoch: 69, Iteration: 10, Loss: 1.06005859375
# Epoch 69 completed in 382.44 seconds, mean loss: 1.2545668345231276
# Epoch: 70, Iteration: 0, Loss: 1.4135000705718994
# Epoch: 70, Iteration: 10, Loss: 1.2539204359054565
# Epoch 70 completed in 371.12 seconds, mean loss: 1.2737311674998357
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_70.pt
# Epoch: 71, Iteration: 0, Loss: 1.2342485189437866
# Epoch: 71, Iteration: 10, Loss: 1.275665283203125
# Epoch 71 completed in 380.27 seconds, mean loss: 1.2927869374935443
# Epoch: 72, Iteration: 0, Loss: 1.367272138595581
# Epoch: 72, Iteration: 10, Loss: 1.1695500612258911
# Epoch 72 completed in 384.37 seconds, mean loss: 1.2771494021782508
# Epoch: 73, Iteration: 0, Loss: 1.2788164615631104
# Epoch: 73, Iteration: 10, Loss: 1.1910516023635864
# Epoch 73 completed in 372.44 seconds, mean loss: 1.2641682808215802
# Epoch: 74, Iteration: 0, Loss: 1.222337245941162
# Epoch: 74, Iteration: 10, Loss: 1.3720355033874512
# Epoch 74 completed in 372.70 seconds, mean loss: 1.281341369335468
# Epoch: 75, Iteration: 0, Loss: 1.312118649482727
# Epoch: 75, Iteration: 10, Loss: 1.2724350690841675
# Epoch 75 completed in 371.25 seconds, mean loss: 1.280874912555401
# Epoch: 76, Iteration: 0, Loss: 1.0010497570037842
# Epoch: 76, Iteration: 10, Loss: 1.1133673191070557
# Epoch 76 completed in 379.22 seconds, mean loss: 1.21393843797537
# Epoch: 77, Iteration: 0, Loss: 1.1908445358276367
# Epoch: 77, Iteration: 10, Loss: 1.3051857948303223
# Epoch 77 completed in 374.34 seconds, mean loss: 1.2136249450536876
# Epoch: 78, Iteration: 0, Loss: 1.2662185430526733
# Epoch: 78, Iteration: 10, Loss: 1.2400953769683838
# Epoch 78 completed in 384.62 seconds, mean loss: 1.2155897112993093
# Epoch: 79, Iteration: 0, Loss: 1.2879447937011719
# Epoch: 79, Iteration: 10, Loss: 1.2317230701446533
# Epoch 79 completed in 367.01 seconds, mean loss: 1.243155130973229
# Epoch: 80, Iteration: 0, Loss: 1.318095326423645
# Epoch: 80, Iteration: 10, Loss: 1.2315698862075806
# Epoch 80 completed in 377.43 seconds, mean loss: 1.1967068864749029
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_80.pt
# Epoch: 81, Iteration: 0, Loss: 1.1398228406906128
# Epoch: 81, Iteration: 10, Loss: 1.293653964996338
# Epoch 81 completed in 394.66 seconds, mean loss: 1.2150008357488191
# Epoch: 82, Iteration: 0, Loss: 1.1114474534988403
# Epoch: 82, Iteration: 10, Loss: 1.1436604261398315
# Epoch 82 completed in 408.02 seconds, mean loss: 1.2065034371155958
# Epoch: 83, Iteration: 0, Loss: 1.3210110664367676
# Epoch: 83, Iteration: 10, Loss: 1.2560019493103027
# Epoch 83 completed in 380.45 seconds, mean loss: 1.2128109748546894
# Epoch: 84, Iteration: 0, Loss: 1.2857086658477783
# Epoch: 84, Iteration: 10, Loss: 1.2505487203598022
# Epoch 84 completed in 382.57 seconds, mean loss: 1.2475977127368634
# Epoch: 85, Iteration: 0, Loss: 1.152765154838562
# Epoch: 85, Iteration: 10, Loss: 1.2015444040298462
# Epoch 85 completed in 378.15 seconds, mean loss: 1.2059911214388335
# Epoch: 86, Iteration: 0, Loss: 1.0667378902435303
# Epoch: 86, Iteration: 10, Loss: 1.1336538791656494
# Epoch 86 completed in 372.73 seconds, mean loss: 1.1828194214747503
# Epoch: 87, Iteration: 0, Loss: 1.3361414670944214
# Epoch: 87, Iteration: 10, Loss: 0.986076831817627
# Epoch 87 completed in 377.46 seconds, mean loss: 1.1760417406375592
# Epoch: 88, Iteration: 0, Loss: 1.1220669746398926
# Epoch: 88, Iteration: 10, Loss: 1.3479945659637451
# Epoch 88 completed in 364.23 seconds, mean loss: 1.1859928690470183
# Epoch: 89, Iteration: 0, Loss: 1.2138309478759766
# Epoch: 89, Iteration: 10, Loss: 1.2279887199401855
# Epoch 89 completed in 373.95 seconds, mean loss: 1.1678511775456941
# Epoch: 90, Iteration: 0, Loss: 1.1356436014175415
# Epoch: 90, Iteration: 10, Loss: 1.08407461643219
# Epoch 90 completed in 380.55 seconds, mean loss: 1.149558920126695
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_90.pt
# Epoch: 91, Iteration: 0, Loss: 1.1475839614868164
# Epoch: 91, Iteration: 10, Loss: 1.317967176437378
# Epoch 91 completed in 372.06 seconds, mean loss: 1.1883117052224965
# Epoch: 92, Iteration: 0, Loss: 1.0852190256118774
# Epoch: 92, Iteration: 10, Loss: 1.2712560892105103
# Epoch 92 completed in 361.04 seconds, mean loss: 1.1959787102845998
# Epoch: 93, Iteration: 0, Loss: 1.0676019191741943
# Epoch: 93, Iteration: 10, Loss: 1.2894800901412964
# Epoch 93 completed in 382.15 seconds, mean loss: 1.1205618977546692
# Epoch: 94, Iteration: 0, Loss: 1.1371792554855347
# Epoch: 94, Iteration: 10, Loss: 1.0839530229568481
# Epoch 94 completed in 374.35 seconds, mean loss: 1.09701072711211
# Epoch: 95, Iteration: 0, Loss: 1.0536564588546753
# Epoch: 95, Iteration: 10, Loss: 1.191786766052246
# Epoch 95 completed in 366.98 seconds, mean loss: 1.1552676420945387
# Epoch: 96, Iteration: 0, Loss: 1.1363584995269775
# Epoch: 96, Iteration: 10, Loss: 1.066408395767212
# Epoch 96 completed in 383.84 seconds, mean loss: 1.1281776519922109
# Epoch: 97, Iteration: 0, Loss: 1.0903730392456055
# Epoch: 97, Iteration: 10, Loss: 1.1767851114273071
# Epoch 97 completed in 377.38 seconds, mean loss: 1.1329895120400648
# Epoch: 98, Iteration: 0, Loss: 1.1634920835494995
# Epoch: 98, Iteration: 10, Loss: 1.3121434450149536
# Epoch 98 completed in 376.44 seconds, mean loss: 1.1754871836075416
# Epoch: 99, Iteration: 0, Loss: 1.1256440877914429
# Epoch: 99, Iteration: 10, Loss: 0.9240649342536926
# Epoch 99 completed in 368.80 seconds, mean loss: 1.161563217639923
# Epoch: 100, Iteration: 0, Loss: 1.2193738222122192
# Epoch: 100, Iteration: 10, Loss: 1.2047032117843628
# Epoch 100 completed in 364.96 seconds, mean loss: 1.14381415110368
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_100.pt
# Epoch: 101, Iteration: 0, Loss: 1.1650515794754028
# Epoch: 101, Iteration: 10, Loss: 1.0230979919433594
# Epoch 101 completed in 381.66 seconds, mean loss: 1.1079794489420378
# Epoch: 102, Iteration: 0, Loss: 1.0539605617523193
# Epoch: 102, Iteration: 10, Loss: 1.1141095161437988
# Epoch 102 completed in 369.09 seconds, mean loss: 1.0903255435136647
# Epoch: 103, Iteration: 0, Loss: 1.0711637735366821
# Epoch: 103, Iteration: 10, Loss: 0.846534252166748
# Epoch 103 completed in 376.35 seconds, mean loss: 1.1173940438490648
# Epoch: 104, Iteration: 0, Loss: 1.0078684091567993
# Epoch: 104, Iteration: 10, Loss: 1.1204216480255127
# Epoch 104 completed in 369.83 seconds, mean loss: 1.0679703308985784
# Epoch: 105, Iteration: 0, Loss: 1.0538238286972046
# Epoch: 105, Iteration: 10, Loss: 1.1205703020095825
# Epoch 105 completed in 377.81 seconds, mean loss: 1.109141890819256
# Epoch: 106, Iteration: 0, Loss: 1.0189248323440552
# Epoch: 106, Iteration: 10, Loss: 0.9591489434242249
# Epoch 106 completed in 361.72 seconds, mean loss: 1.1022975628192608
# Epoch: 107, Iteration: 0, Loss: 1.1107828617095947
# Epoch: 107, Iteration: 10, Loss: 1.154247522354126
# Epoch 107 completed in 382.31 seconds, mean loss: 1.0794108097369854
# Epoch: 108, Iteration: 0, Loss: 1.1517643928527832
# Epoch: 108, Iteration: 10, Loss: 1.176275610923767
# Epoch 108 completed in 370.33 seconds, mean loss: 1.1015412853314326
# Epoch: 109, Iteration: 0, Loss: 1.0428425073623657
# Epoch: 109, Iteration: 10, Loss: 1.0375133752822876
# Epoch 109 completed in 378.64 seconds, mean loss: 1.0469328715251043
# Epoch: 110, Iteration: 0, Loss: 0.8257569670677185
# Epoch: 110, Iteration: 10, Loss: 1.0456700325012207
# Epoch 110 completed in 363.61 seconds, mean loss: 1.0977720251450171
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_110.pt
# Epoch: 111, Iteration: 0, Loss: 1.2107380628585815
# Epoch: 111, Iteration: 10, Loss: 1.122070550918579
# Epoch 111 completed in 363.09 seconds, mean loss: 1.0996578473311205
# Epoch: 112, Iteration: 0, Loss: 1.1242750883102417
# Epoch: 112, Iteration: 10, Loss: 1.0208052396774292
# Epoch 112 completed in 375.75 seconds, mean loss: 1.1018414910023029
# Epoch: 113, Iteration: 0, Loss: 1.2365416288375854
# Epoch: 113, Iteration: 10, Loss: 1.0702146291732788
# Epoch 113 completed in 369.77 seconds, mean loss: 1.108011809679178
# Epoch: 114, Iteration: 0, Loss: 1.2021766901016235
# Epoch: 114, Iteration: 10, Loss: 0.9446321129798889
# Epoch 114 completed in 365.95 seconds, mean loss: 1.1203190225821276
# Epoch: 115, Iteration: 0, Loss: 1.041757583618164
# Epoch: 115, Iteration: 10, Loss: 1.221085786819458
# Epoch 115 completed in 372.06 seconds, mean loss: 1.0692409231112554
# Epoch: 116, Iteration: 0, Loss: 1.0782357454299927
# Epoch: 116, Iteration: 10, Loss: 1.144870638847351
# Epoch 116 completed in 378.07 seconds, mean loss: 1.0865588371570294
# Epoch: 117, Iteration: 0, Loss: 1.1001160144805908
# Epoch: 117, Iteration: 10, Loss: 0.9987824559211731
# Epoch 117 completed in 383.31 seconds, mean loss: 1.0519856948118944
# Epoch: 118, Iteration: 0, Loss: 0.9702205657958984
# Epoch: 118, Iteration: 10, Loss: 0.8629605174064636
# Epoch 118 completed in 392.28 seconds, mean loss: 1.049938637476701
# Epoch: 119, Iteration: 0, Loss: 0.9412454962730408
# Epoch: 119, Iteration: 10, Loss: 0.9771412014961243
# Epoch 119 completed in 368.13 seconds, mean loss: 1.0789580161754901
# Epoch: 120, Iteration: 0, Loss: 1.0743952989578247
# Epoch: 120, Iteration: 10, Loss: 0.994027316570282
# Epoch 120 completed in 381.01 seconds, mean loss: 1.043056295468257
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_120.pt
# Epoch: 121, Iteration: 0, Loss: 0.9187474250793457
# Epoch: 121, Iteration: 10, Loss: 1.0612266063690186
# Epoch 121 completed in 360.41 seconds, mean loss: 1.1021453738212585
# Epoch: 122, Iteration: 0, Loss: 1.1546968221664429
# Epoch: 122, Iteration: 10, Loss: 0.9923816919326782
# Epoch 122 completed in 367.26 seconds, mean loss: 1.0631892314324012
# Epoch: 123, Iteration: 0, Loss: 1.17511785030365
# Epoch: 123, Iteration: 10, Loss: 0.9806708097457886
# Epoch 123 completed in 363.26 seconds, mean loss: 1.057515093913445
# Epoch: 124, Iteration: 0, Loss: 1.1443471908569336
# Epoch: 124, Iteration: 10, Loss: 0.9824469685554504
# Epoch 124 completed in 370.96 seconds, mean loss: 1.0445230970015893
# Epoch: 125, Iteration: 0, Loss: 0.9462981820106506
# Epoch: 125, Iteration: 10, Loss: 1.2191040515899658
# Epoch 125 completed in 376.61 seconds, mean loss: 1.0524971714386573
# Epoch: 126, Iteration: 0, Loss: 1.0643353462219238
# Epoch: 126, Iteration: 10, Loss: 1.104701280593872
# Epoch 126 completed in 374.02 seconds, mean loss: 1.0324285809810345
# Epoch: 127, Iteration: 0, Loss: 1.1262925863265991
# Epoch: 127, Iteration: 10, Loss: 0.8421961069107056
# Epoch 127 completed in 371.78 seconds, mean loss: 1.0535225822375371
# Epoch: 128, Iteration: 0, Loss: 1.110303521156311
# Epoch: 128, Iteration: 10, Loss: 0.9586897492408752
# Epoch 128 completed in 384.40 seconds, mean loss: 1.0261144225413983
# Epoch: 129, Iteration: 0, Loss: 1.1776877641677856
# Epoch: 129, Iteration: 10, Loss: 1.0374234914779663
# Epoch 129 completed in 375.69 seconds, mean loss: 1.0492932934027452
# Epoch: 130, Iteration: 0, Loss: 1.1019319295883179
# Epoch: 130, Iteration: 10, Loss: 1.1662836074829102
# Epoch 130 completed in 364.45 seconds, mean loss: 1.0504990541017973
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_130.pt
# Epoch: 131, Iteration: 0, Loss: 1.0173910856246948
# Epoch: 131, Iteration: 10, Loss: 1.0097914934158325
# Epoch 131 completed in 384.37 seconds, mean loss: 1.044169082091405
# Epoch: 132, Iteration: 0, Loss: 1.0112626552581787
# Epoch: 132, Iteration: 10, Loss: 0.9983872771263123
# Epoch 132 completed in 384.35 seconds, mean loss: 1.0030855307212243
# Epoch: 133, Iteration: 0, Loss: 1.0992668867111206
# Epoch: 133, Iteration: 10, Loss: 0.9129318594932556
# Epoch 133 completed in 371.34 seconds, mean loss: 1.039725349499629
# Epoch: 134, Iteration: 0, Loss: 1.1885825395584106
# Epoch: 134, Iteration: 10, Loss: 0.9348803758621216
# Epoch 134 completed in 366.45 seconds, mean loss: 1.0284886818665724
# Epoch: 135, Iteration: 0, Loss: 1.1178197860717773
# Epoch: 135, Iteration: 10, Loss: 1.0040544271469116
# Epoch 135 completed in 367.43 seconds, mean loss: 1.012555874311007
# Epoch: 136, Iteration: 0, Loss: 1.0793848037719727
# Epoch: 136, Iteration: 10, Loss: 1.0246134996414185
# Epoch 136 completed in 370.95 seconds, mean loss: 1.0456413076474116
# Epoch: 137, Iteration: 0, Loss: 1.196805715560913
# Epoch: 137, Iteration: 10, Loss: 1.0340750217437744
# Epoch 137 completed in 382.92 seconds, mean loss: 1.0305049327703624
# Epoch: 138, Iteration: 0, Loss: 0.9937883615493774
# Epoch: 138, Iteration: 10, Loss: 1.0191810131072998
# Epoch 138 completed in 369.34 seconds, mean loss: 1.0460191002258887
# Epoch: 139, Iteration: 0, Loss: 1.0248678922653198
# Epoch: 139, Iteration: 10, Loss: 1.1767423152923584
# Epoch 139 completed in 358.19 seconds, mean loss: 1.0300355140979474
# Epoch: 140, Iteration: 0, Loss: 0.9242377877235413
# Epoch: 140, Iteration: 10, Loss: 0.9043868184089661
# Epoch 140 completed in 380.01 seconds, mean loss: 0.9922530559393076
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_140.pt
# Epoch: 141, Iteration: 0, Loss: 0.9042432904243469
# Epoch: 141, Iteration: 10, Loss: 1.0458332300186157
# Epoch 141 completed in 374.51 seconds, mean loss: 1.0382865759042592
# Epoch: 142, Iteration: 0, Loss: 0.9786255955696106
# Epoch: 142, Iteration: 10, Loss: 0.9263588786125183
# Epoch 142 completed in 374.64 seconds, mean loss: 1.0024778017630944
# Epoch: 143, Iteration: 0, Loss: 0.9718685746192932
# Epoch: 143, Iteration: 10, Loss: 0.9183405041694641
# Epoch 143 completed in 368.36 seconds, mean loss: 1.0223987056658819
# Epoch: 144, Iteration: 0, Loss: 0.9430896639823914
# Epoch: 144, Iteration: 10, Loss: 0.9549362659454346
# Epoch 144 completed in 380.39 seconds, mean loss: 0.9941767683395972
# Epoch: 145, Iteration: 0, Loss: 1.2125859260559082
# Epoch: 145, Iteration: 10, Loss: 0.9875982403755188
# Epoch 145 completed in 361.41 seconds, mean loss: 1.0191291662362905
# Epoch: 146, Iteration: 0, Loss: 1.0935602188110352
# Epoch: 146, Iteration: 10, Loss: 0.9854233860969543
# Epoch 146 completed in 384.07 seconds, mean loss: 0.9936873041666471
# Epoch: 147, Iteration: 0, Loss: 1.120340347290039
# Epoch: 147, Iteration: 10, Loss: 0.9836865663528442
# Epoch 147 completed in 374.44 seconds, mean loss: 1.0450404836581304
# Epoch: 148, Iteration: 0, Loss: 0.7653975486755371
# Epoch: 148, Iteration: 10, Loss: 0.9538506269454956
# Epoch 148 completed in 379.55 seconds, mean loss: 0.9634598035078782
# Epoch: 149, Iteration: 0, Loss: 1.0867654085159302
# Epoch: 149, Iteration: 10, Loss: 0.9799253344535828
# Epoch 149 completed in 360.56 seconds, mean loss: 1.022761372419504
# Epoch: 150, Iteration: 0, Loss: 1.023714303970337
# Epoch: 150, Iteration: 10, Loss: 0.9951417446136475
# Epoch 150 completed in 397.23 seconds, mean loss: 0.9725132859670199
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_150.pt
# Epoch: 151, Iteration: 0, Loss: 0.7456693053245544
# Epoch: 151, Iteration: 10, Loss: 0.9906215071678162
# Epoch 151 completed in 363.58 seconds, mean loss: 0.9631359118681687
# Epoch: 152, Iteration: 0, Loss: 0.9118517637252808
# Epoch: 152, Iteration: 10, Loss: 0.7674254179000854
# Epoch 152 completed in 374.98 seconds, mean loss: 1.0050029983887305
# Epoch: 153, Iteration: 0, Loss: 0.8764890432357788
# Epoch: 153, Iteration: 10, Loss: 0.7595479488372803
# Epoch 153 completed in 371.35 seconds, mean loss: 0.9839366170076224
# Epoch: 154, Iteration: 0, Loss: 1.073337197303772
# Epoch: 154, Iteration: 10, Loss: 1.0280300378799438
# Epoch 154 completed in 381.40 seconds, mean loss: 0.9872925189825205
# Epoch: 155, Iteration: 0, Loss: 0.9364832043647766
# Epoch: 155, Iteration: 10, Loss: 0.9574137926101685
# Epoch 155 completed in 371.50 seconds, mean loss: 0.9961672654518714
# Epoch: 156, Iteration: 0, Loss: 0.9454301595687866
# Epoch: 156, Iteration: 10, Loss: 0.9990242123603821
# Epoch 156 completed in 378.81 seconds, mean loss: 0.9696096869615408
# Epoch: 157, Iteration: 0, Loss: 0.988977313041687
# Epoch: 157, Iteration: 10, Loss: 0.8425567150115967
# Epoch 157 completed in 392.93 seconds, mean loss: 0.9728136704518244
# Epoch: 158, Iteration: 0, Loss: 1.0011708736419678
# Epoch: 158, Iteration: 10, Loss: 0.9244419932365417
# Epoch 158 completed in 357.79 seconds, mean loss: 0.9922817028485812
# Epoch: 159, Iteration: 0, Loss: 1.0352013111114502
# Epoch: 159, Iteration: 10, Loss: 0.7602733373641968
# Epoch 159 completed in 372.77 seconds, mean loss: 0.9891774516839248
# Epoch: 160, Iteration: 0, Loss: 0.9213688373565674
# Epoch: 160, Iteration: 10, Loss: 1.029330849647522
# Epoch 160 completed in 374.98 seconds, mean loss: 0.9676684462107145
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_160.pt
# Epoch: 161, Iteration: 0, Loss: 0.8785272240638733
# Epoch: 161, Iteration: 10, Loss: 0.9901121258735657
# Epoch 161 completed in 369.58 seconds, mean loss: 0.9982472245509808
# Epoch: 162, Iteration: 0, Loss: 0.9273809194564819
# Epoch: 162, Iteration: 10, Loss: 1.0380539894104004
# Epoch 162 completed in 374.92 seconds, mean loss: 0.9894998577924875
# Epoch: 163, Iteration: 0, Loss: 0.9562467932701111
# Epoch: 163, Iteration: 10, Loss: 0.8792775869369507
# Epoch 163 completed in 356.90 seconds, mean loss: 0.9790867429513198
# Epoch: 164, Iteration: 0, Loss: 0.9294272661209106
# Epoch: 164, Iteration: 10, Loss: 1.044650673866272
# Epoch 164 completed in 388.16 seconds, mean loss: 0.9598783758970407
# Epoch: 165, Iteration: 0, Loss: 0.861104428768158
# Epoch: 165, Iteration: 10, Loss: 1.0038177967071533
# Epoch 165 completed in 369.89 seconds, mean loss: 0.9541058540344238
# Epoch: 166, Iteration: 0, Loss: 1.072913646697998
# Epoch: 166, Iteration: 10, Loss: 0.854399561882019
# Epoch 166 completed in 378.38 seconds, mean loss: 0.94548211647914
# Epoch: 167, Iteration: 0, Loss: 1.1258492469787598
# Epoch: 167, Iteration: 10, Loss: 0.9856560230255127
# Epoch 167 completed in 374.65 seconds, mean loss: 0.977983126273522
# Epoch: 168, Iteration: 0, Loss: 0.9763028025627136
# Epoch: 168, Iteration: 10, Loss: 0.826735258102417
# Epoch 168 completed in 369.22 seconds, mean loss: 0.9668019734896146
# Epoch: 169, Iteration: 0, Loss: 0.9665313363075256
# Epoch: 169, Iteration: 10, Loss: 1.0594370365142822
# Epoch 169 completed in 371.29 seconds, mean loss: 0.95888352394104
# Epoch: 170, Iteration: 0, Loss: 0.9163185358047485
# Epoch: 170, Iteration: 10, Loss: 0.9650143980979919
# Epoch 170 completed in 372.43 seconds, mean loss: 0.9426840131099408
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_170.pt
# Epoch: 171, Iteration: 0, Loss: 0.8184995055198669
# Epoch: 171, Iteration: 10, Loss: 0.8699637055397034
# Epoch 171 completed in 392.61 seconds, mean loss: 0.9235335267507113
# Epoch: 172, Iteration: 0, Loss: 1.0673810243606567
# Epoch: 172, Iteration: 10, Loss: 1.0034259557724
# Epoch 172 completed in 376.06 seconds, mean loss: 1.000914724973532
# Epoch: 173, Iteration: 0, Loss: 0.8128855228424072
# Epoch: 173, Iteration: 10, Loss: 0.9226769208908081
# Epoch 173 completed in 375.02 seconds, mean loss: 0.9731383736316974
# Epoch: 174, Iteration: 0, Loss: 0.9323431253433228
# Epoch: 174, Iteration: 10, Loss: 0.9837642312049866
# Epoch 174 completed in 375.96 seconds, mean loss: 0.9497180351844201
# Epoch: 175, Iteration: 0, Loss: 0.9508192539215088
# Epoch: 175, Iteration: 10, Loss: 0.7774978280067444
# Epoch 175 completed in 364.46 seconds, mean loss: 0.9459560971993667
# Epoch: 176, Iteration: 0, Loss: 1.015740156173706
# Epoch: 176, Iteration: 10, Loss: 1.012854814529419
# Epoch 176 completed in 366.58 seconds, mean loss: 0.9520231164418734
# Epoch: 177, Iteration: 0, Loss: 0.9292985200881958
# Epoch: 177, Iteration: 10, Loss: 1.1196961402893066
# Epoch 177 completed in 373.74 seconds, mean loss: 0.9603105737612798
# Epoch: 178, Iteration: 0, Loss: 0.9234670996665955
# Epoch: 178, Iteration: 10, Loss: 0.9684563875198364
# Epoch 178 completed in 365.72 seconds, mean loss: 0.9297617857272809
# Epoch: 179, Iteration: 0, Loss: 0.9517648816108704
# Epoch: 179, Iteration: 10, Loss: 0.8446206450462341
# Epoch 179 completed in 380.58 seconds, mean loss: 0.9031208111689641
# Epoch: 180, Iteration: 0, Loss: 0.8608512282371521
# Epoch: 180, Iteration: 10, Loss: 0.9432361125946045
# Epoch 180 completed in 368.37 seconds, mean loss: 0.9208377874814547
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_180.pt
# Epoch: 181, Iteration: 0, Loss: 0.9159412980079651
# Epoch: 181, Iteration: 10, Loss: 1.0231801271438599
# Epoch 181 completed in 370.28 seconds, mean loss: 0.9308956448848431
# Epoch: 182, Iteration: 0, Loss: 0.9602596163749695
# Epoch: 182, Iteration: 10, Loss: 0.8596630692481995
# Epoch 182 completed in 373.60 seconds, mean loss: 0.9407412088834323
# Epoch: 183, Iteration: 0, Loss: 0.9097022414207458
# Epoch: 183, Iteration: 10, Loss: 0.861038327217102
# Epoch 183 completed in 367.79 seconds, mean loss: 0.925030896296868
# Epoch: 184, Iteration: 0, Loss: 0.8759801983833313
# Epoch: 184, Iteration: 10, Loss: 0.8616142272949219
# Epoch 184 completed in 380.88 seconds, mean loss: 0.917451276228978
# Epoch: 185, Iteration: 0, Loss: 0.8716466426849365
# Epoch: 185, Iteration: 10, Loss: 1.0421632528305054
# Epoch 185 completed in 377.23 seconds, mean loss: 0.9154851207366357
# Epoch: 186, Iteration: 0, Loss: 0.9255515933036804
# Epoch: 186, Iteration: 10, Loss: 0.8689764738082886
# Epoch 186 completed in 366.51 seconds, mean loss: 0.9377663318927472
# Epoch: 187, Iteration: 0, Loss: 0.8854761719703674
# Epoch: 187, Iteration: 10, Loss: 1.0178784132003784
# Epoch 187 completed in 367.30 seconds, mean loss: 0.925418156843919
# Epoch: 188, Iteration: 0, Loss: 0.714147686958313
# Epoch: 188, Iteration: 10, Loss: 0.9247450232505798
# Epoch 188 completed in 365.83 seconds, mean loss: 0.9132110522343562
# Epoch: 189, Iteration: 0, Loss: 1.0067393779754639
# Epoch: 189, Iteration: 10, Loss: 0.8090807199478149
# Epoch 189 completed in 366.39 seconds, mean loss: 0.9538172987791208
# Epoch: 190, Iteration: 0, Loss: 0.9310106039047241
# Epoch: 190, Iteration: 10, Loss: 0.8597451448440552
# Epoch 190 completed in 389.08 seconds, mean loss: 0.8958608874907861
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_190.pt
# Epoch: 191, Iteration: 0, Loss: 0.762407660484314
# Epoch: 191, Iteration: 10, Loss: 0.9703380465507507
# Epoch 191 completed in 390.71 seconds, mean loss: 0.9017835396986741
# Epoch: 192, Iteration: 0, Loss: 0.7569694519042969
# Epoch: 192, Iteration: 10, Loss: 0.8941713571548462
# Epoch 192 completed in 388.89 seconds, mean loss: 0.9092154823816739
# Epoch: 193, Iteration: 0, Loss: 0.9801475405693054
# Epoch: 193, Iteration: 10, Loss: 0.8552517294883728
# Epoch 193 completed in 363.63 seconds, mean loss: 0.9002320720599248
# Epoch: 194, Iteration: 0, Loss: 0.9753167629241943
# Epoch: 194, Iteration: 10, Loss: 1.027391791343689
# Epoch 194 completed in 368.29 seconds, mean loss: 0.8953880805235642
# Epoch: 195, Iteration: 0, Loss: 1.018673062324524
# Epoch: 195, Iteration: 10, Loss: 1.041632890701294
# Epoch 195 completed in 371.63 seconds, mean loss: 0.9044401049613953
# Epoch: 196, Iteration: 0, Loss: 0.9201998710632324
# Epoch: 196, Iteration: 10, Loss: 1.0509535074234009
# Epoch 196 completed in 371.74 seconds, mean loss: 0.9043731093406677
# Epoch: 197, Iteration: 0, Loss: 1.0149823427200317
# Epoch: 197, Iteration: 10, Loss: 0.9352864027023315
# Epoch 197 completed in 369.12 seconds, mean loss: 0.8986834975389334
# Epoch: 198, Iteration: 0, Loss: 0.8879168033599854
# Epoch: 198, Iteration: 10, Loss: 0.7645895481109619
# Epoch 198 completed in 371.87 seconds, mean loss: 0.920376181602478
# Epoch: 199, Iteration: 0, Loss: 0.9479215741157532
# Epoch: 199, Iteration: 10, Loss: 1.0625790357589722
# Epoch 199 completed in 388.88 seconds, mean loss: 0.9072387401874249
# Epoch: 200, Iteration: 0, Loss: 0.7151474356651306
# Epoch: 200, Iteration: 10, Loss: 0.8763520121574402
# Epoch 200 completed in 381.37 seconds, mean loss: 0.8855193073932941
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_200.pt
# Epoch: 201, Iteration: 0, Loss: 1.023031234741211
# Epoch: 201, Iteration: 10, Loss: 0.9595257639884949
# Epoch 201 completed in 375.01 seconds, mean loss: 0.8953522993968084
# Epoch: 202, Iteration: 0, Loss: 1.0231302976608276
# Epoch: 202, Iteration: 10, Loss: 0.7298576831817627
# Epoch 202 completed in 375.78 seconds, mean loss: 0.890640900685237
# Epoch: 203, Iteration: 0, Loss: 0.948499321937561
# Epoch: 203, Iteration: 10, Loss: 0.8576999306678772
# Epoch 203 completed in 373.40 seconds, mean loss: 0.8813669819098252
# Epoch: 204, Iteration: 0, Loss: 0.8664641976356506
# Epoch: 204, Iteration: 10, Loss: 0.8172541856765747
# Epoch 204 completed in 374.28 seconds, mean loss: 0.9197799976055439
# Epoch: 205, Iteration: 0, Loss: 0.9672383069992065
# Epoch: 205, Iteration: 10, Loss: 0.9478336572647095
# Epoch 205 completed in 376.22 seconds, mean loss: 0.8964416889043955
# Epoch: 206, Iteration: 0, Loss: 0.8211416602134705
# Epoch: 206, Iteration: 10, Loss: 0.7693078517913818
# Epoch 206 completed in 373.29 seconds, mean loss: 0.8696990379920373
# Epoch: 207, Iteration: 0, Loss: 0.8900290131568909
# Epoch: 207, Iteration: 10, Loss: 0.7939262986183167
# Epoch 207 completed in 383.40 seconds, mean loss: 0.8805993291047903
# Epoch: 208, Iteration: 0, Loss: 0.8136511445045471
# Epoch: 208, Iteration: 10, Loss: 0.9708983898162842
# Epoch 208 completed in 373.51 seconds, mean loss: 0.8927302635633029
# Epoch: 209, Iteration: 0, Loss: 0.9746972322463989
# Epoch: 209, Iteration: 10, Loss: 0.8908998966217041
# Epoch 209 completed in 369.85 seconds, mean loss: 0.8821345521853521
# Epoch: 210, Iteration: 0, Loss: 0.85188227891922
# Epoch: 210, Iteration: 10, Loss: 0.9863893389701843
# Epoch 210 completed in 376.07 seconds, mean loss: 0.9142301770356985
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_210.pt
# Epoch: 211, Iteration: 0, Loss: 0.6882057189941406
# Epoch: 211, Iteration: 10, Loss: 0.942658543586731
# Epoch 211 completed in 368.65 seconds, mean loss: 0.8822875206287091
# Epoch: 212, Iteration: 0, Loss: 0.903032660484314
# Epoch: 212, Iteration: 10, Loss: 0.8324355483055115
# Epoch 212 completed in 391.58 seconds, mean loss: 0.8609182697076064
# Epoch: 213, Iteration: 0, Loss: 0.750903308391571
# Epoch: 213, Iteration: 10, Loss: 0.9417088627815247
# Epoch 213 completed in 364.77 seconds, mean loss: 0.9103909272413987
# Epoch: 214, Iteration: 0, Loss: 0.8948141932487488
# Epoch: 214, Iteration: 10, Loss: 0.8003007173538208
# Epoch 214 completed in 378.05 seconds, mean loss: 0.8511921534171472
# Epoch: 215, Iteration: 0, Loss: 0.8187633752822876
# Epoch: 215, Iteration: 10, Loss: 1.0238029956817627
# Epoch 215 completed in 364.09 seconds, mean loss: 0.8989819609201871
# Epoch: 216, Iteration: 0, Loss: 0.8626617789268494
# Epoch: 216, Iteration: 10, Loss: 0.7022238373756409
# Epoch 216 completed in 378.79 seconds, mean loss: 0.8642715444931617
# Epoch: 217, Iteration: 0, Loss: 0.8884451985359192
# Epoch: 217, Iteration: 10, Loss: 0.8934937119483948
# Epoch 217 completed in 374.57 seconds, mean loss: 0.8872068386811477
# Epoch: 218, Iteration: 0, Loss: 0.8391812443733215
# Epoch: 218, Iteration: 10, Loss: 0.8697345852851868
# Epoch 218 completed in 372.79 seconds, mean loss: 0.8808932304382324
# Epoch: 219, Iteration: 0, Loss: 0.8015189170837402
# Epoch: 219, Iteration: 10, Loss: 0.9855599403381348
# Epoch 219 completed in 380.69 seconds, mean loss: 0.8538195582536551
# Epoch: 220, Iteration: 0, Loss: 0.8340108394622803
# Epoch: 220, Iteration: 10, Loss: 0.7926309108734131
# Epoch 220 completed in 374.70 seconds, mean loss: 0.8773952722549438
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_220.pt
# Epoch: 221, Iteration: 0, Loss: 1.0457801818847656
# Epoch: 221, Iteration: 10, Loss: 0.8086578249931335
# Epoch 221 completed in 377.85 seconds, mean loss: 0.9032843479743371
# Epoch: 222, Iteration: 0, Loss: 0.6956096887588501
# Epoch: 222, Iteration: 10, Loss: 0.8207195401191711
# Epoch 222 completed in 370.39 seconds, mean loss: 0.890465511725499
# Epoch: 223, Iteration: 0, Loss: 0.9397591948509216
# Epoch: 223, Iteration: 10, Loss: 0.8415259122848511
# Epoch 223 completed in 384.51 seconds, mean loss: 0.896269848713508
# Epoch: 224, Iteration: 0, Loss: 0.9908137321472168
# Epoch: 224, Iteration: 10, Loss: 0.8506107330322266
# Epoch 224 completed in 384.98 seconds, mean loss: 0.8406849136719337
# Epoch: 225, Iteration: 0, Loss: 0.9060486555099487
# Epoch: 225, Iteration: 10, Loss: 0.9648230671882629
# Epoch 225 completed in 370.97 seconds, mean loss: 0.8739149845563449
# Epoch: 226, Iteration: 0, Loss: 0.8271042704582214
# Epoch: 226, Iteration: 10, Loss: 0.8664708137512207
# Epoch 226 completed in 372.81 seconds, mean loss: 0.8578210885708148
# Epoch: 227, Iteration: 0, Loss: 0.9448198080062866
# Epoch: 227, Iteration: 10, Loss: 0.9236047267913818
# Epoch 227 completed in 375.76 seconds, mean loss: 0.8478756363575275
# Epoch: 228, Iteration: 0, Loss: 0.8934170603752136
# Epoch: 228, Iteration: 10, Loss: 0.8579118847846985
# Epoch 228 completed in 383.13 seconds, mean loss: 0.8644361312572773
# Epoch: 229, Iteration: 0, Loss: 0.7079133987426758
# Epoch: 229, Iteration: 10, Loss: 0.858491063117981
# Epoch 229 completed in 379.22 seconds, mean loss: 0.8595623786632831
# Epoch: 230, Iteration: 0, Loss: 0.8906144499778748
# Epoch: 230, Iteration: 10, Loss: 0.7819059491157532
# Epoch 230 completed in 370.56 seconds, mean loss: 0.8729510949208186
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_230.pt
# Epoch: 231, Iteration: 0, Loss: 0.8203863501548767
# Epoch: 231, Iteration: 10, Loss: 0.8202260732650757
# Epoch 231 completed in 364.45 seconds, mean loss: 0.910433645431812
# Epoch: 232, Iteration: 0, Loss: 0.9745966196060181
# Epoch: 232, Iteration: 10, Loss: 0.8119455575942993
# Epoch 232 completed in 379.70 seconds, mean loss: 0.86324208516341
# Epoch: 233, Iteration: 0, Loss: 0.855262815952301
# Epoch: 233, Iteration: 10, Loss: 0.8267175555229187
# Epoch 233 completed in 381.04 seconds, mean loss: 0.8591092366438645
# Epoch: 234, Iteration: 0, Loss: 1.0291712284088135
# Epoch: 234, Iteration: 10, Loss: 0.8284911513328552
# Epoch 234 completed in 372.27 seconds, mean loss: 0.8426134081987234
# Epoch: 235, Iteration: 0, Loss: 0.654971718788147
# Epoch: 235, Iteration: 10, Loss: 0.7987644672393799
# Epoch 235 completed in 369.25 seconds, mean loss: 0.8397056827178369
# Epoch: 236, Iteration: 0, Loss: 0.9452225565910339
# Epoch: 236, Iteration: 10, Loss: 0.8703190684318542
# Epoch 236 completed in 377.84 seconds, mean loss: 0.8622044279025152
# Epoch: 237, Iteration: 0, Loss: 0.9254230260848999
# Epoch: 237, Iteration: 10, Loss: 0.8942367434501648
# Epoch 237 completed in 379.38 seconds, mean loss: 0.8817883638235239
# Epoch: 238, Iteration: 0, Loss: 0.7806172370910645
# Epoch: 238, Iteration: 10, Loss: 0.821736752986908
# Epoch 238 completed in 365.41 seconds, mean loss: 0.8263664199755743
# Epoch: 239, Iteration: 0, Loss: 0.769786536693573
# Epoch: 239, Iteration: 10, Loss: 0.6904619932174683
# Epoch 239 completed in 371.81 seconds, mean loss: 0.8750470418196458
# Epoch: 240, Iteration: 0, Loss: 0.9783967733383179
# Epoch: 240, Iteration: 10, Loss: 0.7407069206237793
# Epoch 240 completed in 372.14 seconds, mean loss: 0.8518860523517315
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_240.pt
# Epoch: 241, Iteration: 0, Loss: 0.8292868137359619
# Epoch: 241, Iteration: 10, Loss: 0.7789909243583679
# Epoch 241 completed in 368.97 seconds, mean loss: 0.8511424981630765
# Epoch: 242, Iteration: 0, Loss: 0.8022052645683289
# Epoch: 242, Iteration: 10, Loss: 0.8606157302856445
# Epoch 242 completed in 362.34 seconds, mean loss: 0.8544195523628821
# Epoch: 243, Iteration: 0, Loss: 0.7952113747596741
# Epoch: 243, Iteration: 10, Loss: 0.8399592638015747
# Epoch 243 completed in 372.94 seconds, mean loss: 0.8472092976936927
# Epoch: 244, Iteration: 0, Loss: 0.7903251647949219
# Epoch: 244, Iteration: 10, Loss: 0.8858028054237366
# Epoch 244 completed in 383.60 seconds, mean loss: 0.8225850554612967
# Epoch: 245, Iteration: 0, Loss: 0.7463829517364502
# Epoch: 245, Iteration: 10, Loss: 0.8336035013198853
# Epoch 245 completed in 372.78 seconds, mean loss: 0.829667329788208
# Epoch: 246, Iteration: 0, Loss: 0.7343468070030212
# Epoch: 246, Iteration: 10, Loss: 0.844808042049408
# Epoch 246 completed in 359.40 seconds, mean loss: 0.8300246275388278
# Epoch: 247, Iteration: 0, Loss: 0.8988463282585144
# Epoch: 247, Iteration: 10, Loss: 0.9470179677009583
# Epoch 247 completed in 371.62 seconds, mean loss: 0.8429734844427842
# Epoch: 248, Iteration: 0, Loss: 0.8018362522125244
# Epoch: 248, Iteration: 10, Loss: 0.7951546907424927
# Epoch 248 completed in 375.21 seconds, mean loss: 0.8165948070012606
# Epoch: 249, Iteration: 0, Loss: 0.8529144525527954
# Epoch: 249, Iteration: 10, Loss: 0.8066160678863525
# Epoch 249 completed in 360.80 seconds, mean loss: 0.8300093274850112
# Epoch: 250, Iteration: 0, Loss: 0.9179811477661133
# Epoch: 250, Iteration: 10, Loss: 0.7285740971565247
# Epoch 250 completed in 362.49 seconds, mean loss: 0.8618857723016006
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_250.pt
# Epoch: 251, Iteration: 0, Loss: 0.7664989829063416
# Epoch: 251, Iteration: 10, Loss: 0.8922415971755981
# Epoch 251 completed in 358.80 seconds, mean loss: 0.8433104111598089
# Epoch: 252, Iteration: 0, Loss: 0.8120049834251404
# Epoch: 252, Iteration: 10, Loss: 0.6209218502044678
# Epoch 252 completed in 362.56 seconds, mean loss: 0.8170634049635667
# Epoch: 253, Iteration: 0, Loss: 0.8322699069976807
# Epoch: 253, Iteration: 10, Loss: 0.7667986154556274
# Epoch 253 completed in 373.14 seconds, mean loss: 0.8339361089926499
# Epoch: 254, Iteration: 0, Loss: 0.8883084654808044
# Epoch: 254, Iteration: 10, Loss: 0.9175772070884705
# Epoch 254 completed in 385.64 seconds, mean loss: 0.8281820508149954
# Epoch: 255, Iteration: 0, Loss: 0.6618263721466064
# Epoch: 255, Iteration: 10, Loss: 0.7054333686828613
# Epoch 255 completed in 373.07 seconds, mean loss: 0.810555989925678
# Epoch: 256, Iteration: 0, Loss: 0.8916283845901489
# Epoch: 256, Iteration: 10, Loss: 0.7161667346954346
# Epoch 256 completed in 375.98 seconds, mean loss: 0.8298121415651761
# Epoch: 257, Iteration: 0, Loss: 0.7962439656257629
# Epoch: 257, Iteration: 10, Loss: 0.7132614254951477
# Epoch 257 completed in 382.70 seconds, mean loss: 0.8146888888799227
# Epoch: 258, Iteration: 0, Loss: 0.7775071859359741
# Epoch: 258, Iteration: 10, Loss: 0.8711692690849304
# Epoch 258 completed in 367.11 seconds, mean loss: 0.8273395345761225
# Epoch: 259, Iteration: 0, Loss: 0.7642390727996826
# Epoch: 259, Iteration: 10, Loss: 0.8650035262107849
# Epoch 259 completed in 361.39 seconds, mean loss: 0.8428667141841009
# Epoch: 260, Iteration: 0, Loss: 0.8537399172782898
# Epoch: 260, Iteration: 10, Loss: 0.7918024063110352
# Epoch 260 completed in 377.13 seconds, mean loss: 0.8170967652247503
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_260.pt
# Epoch: 261, Iteration: 0, Loss: 0.7944573163986206
# Epoch: 261, Iteration: 10, Loss: 0.7520632743835449
# Epoch 261 completed in 375.26 seconds, mean loss: 0.8711042312475351
# Epoch: 262, Iteration: 0, Loss: 0.94862300157547
# Epoch: 262, Iteration: 10, Loss: 0.7294236421585083
# Epoch 262 completed in 377.78 seconds, mean loss: 0.8259813097807077
# Epoch: 263, Iteration: 0, Loss: 0.8226385116577148
# Epoch: 263, Iteration: 10, Loss: 0.8522440791130066
# Epoch 263 completed in 388.03 seconds, mean loss: 0.8065404525169959
# Epoch: 264, Iteration: 0, Loss: 0.938491940498352
# Epoch: 264, Iteration: 10, Loss: 0.7879757285118103
# Epoch 264 completed in 373.29 seconds, mean loss: 0.826712599167457
# Epoch: 265, Iteration: 0, Loss: 0.7175730466842651
# Epoch: 265, Iteration: 10, Loss: 0.9843501448631287
# Epoch 265 completed in 377.09 seconds, mean loss: 0.8052934591586773
# Epoch: 266, Iteration: 0, Loss: 0.8647448420524597
# Epoch: 266, Iteration: 10, Loss: 0.7430529594421387
# Epoch 266 completed in 368.49 seconds, mean loss: 0.8033036452073318
# Epoch: 267, Iteration: 0, Loss: 0.7511002421379089
# Epoch: 267, Iteration: 10, Loss: 0.8022610545158386
# Epoch 267 completed in 377.25 seconds, mean loss: 0.8137345405725332
# Epoch: 268, Iteration: 0, Loss: 0.7497367262840271
# Epoch: 268, Iteration: 10, Loss: 0.7479151487350464
# Epoch 268 completed in 373.14 seconds, mean loss: 0.7974125697062566
# Epoch: 269, Iteration: 0, Loss: 0.7942972183227539
# Epoch: 269, Iteration: 10, Loss: 0.7533413767814636
# Epoch 269 completed in 365.66 seconds, mean loss: 0.8474133656575129
# Epoch: 270, Iteration: 0, Loss: 0.836254894733429
# Epoch: 270, Iteration: 10, Loss: 0.7728031873703003
# Epoch 270 completed in 367.32 seconds, mean loss: 0.8127339207209073
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_270.pt
# Epoch: 271, Iteration: 0, Loss: 0.7665979266166687
# Epoch: 271, Iteration: 10, Loss: 0.8920881748199463
# Epoch 271 completed in 376.37 seconds, mean loss: 0.7969343203764695
# Epoch: 272, Iteration: 0, Loss: 0.9322612881660461
# Epoch: 272, Iteration: 10, Loss: 0.8729087710380554
# Epoch 272 completed in 359.81 seconds, mean loss: 0.8280113797921401
# Epoch: 273, Iteration: 0, Loss: 0.8039190769195557
# Epoch: 273, Iteration: 10, Loss: 1.0031077861785889
# Epoch 273 completed in 376.33 seconds, mean loss: 0.8179773550767165
# Epoch: 274, Iteration: 0, Loss: 0.7703542113304138
# Epoch: 274, Iteration: 10, Loss: 0.6039751768112183
# Epoch 274 completed in 368.43 seconds, mean loss: 0.7838169519717877
# Epoch: 275, Iteration: 0, Loss: 0.7220771908760071
# Epoch: 275, Iteration: 10, Loss: 0.6985524296760559
# Epoch 275 completed in 368.28 seconds, mean loss: 0.7897595350558941
# Epoch: 276, Iteration: 0, Loss: 0.8802424669265747
# Epoch: 276, Iteration: 10, Loss: 0.6232450008392334
# Epoch 276 completed in 377.54 seconds, mean loss: 0.8027410369652969
# Epoch: 277, Iteration: 0, Loss: 0.6967499256134033
# Epoch: 277, Iteration: 10, Loss: 0.7900692820549011
# Epoch 277 completed in 363.48 seconds, mean loss: 0.8031831108606778
# Epoch: 278, Iteration: 0, Loss: 0.8445897698402405
# Epoch: 278, Iteration: 10, Loss: 0.7390429377555847
# Epoch 278 completed in 376.80 seconds, mean loss: 0.8138490869448736
# Epoch: 279, Iteration: 0, Loss: 0.8750927448272705
# Epoch: 279, Iteration: 10, Loss: 0.847685694694519
# Epoch 279 completed in 355.58 seconds, mean loss: 0.8397060265907874
# Epoch: 280, Iteration: 0, Loss: 0.7850467562675476
# Epoch: 280, Iteration: 10, Loss: 0.6156414747238159
# Epoch 280 completed in 382.08 seconds, mean loss: 0.7978402284475473
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_280.pt
# Epoch: 281, Iteration: 0, Loss: 0.830581545829773
# Epoch: 281, Iteration: 10, Loss: 0.850931704044342
# Epoch 281 completed in 385.44 seconds, mean loss: 0.7992886167306167
# Epoch: 282, Iteration: 0, Loss: 0.6181727051734924
# Epoch: 282, Iteration: 10, Loss: 0.9192247986793518
# Epoch 282 completed in 365.47 seconds, mean loss: 0.8046183815369239
# Epoch: 283, Iteration: 0, Loss: 0.7472966909408569
# Epoch: 283, Iteration: 10, Loss: 0.8442521095275879
# Epoch 283 completed in 377.23 seconds, mean loss: 0.7985311700747564
# Epoch: 284, Iteration: 0, Loss: 0.8929734230041504
# Epoch: 284, Iteration: 10, Loss: 0.835830569267273
# Epoch 284 completed in 370.23 seconds, mean loss: 0.7770502750690167
# Epoch: 285, Iteration: 0, Loss: 0.7274701595306396
# Epoch: 285, Iteration: 10, Loss: 0.7788549661636353
# Epoch 285 completed in 379.59 seconds, mean loss: 0.7775034308433533
# Epoch: 286, Iteration: 0, Loss: 0.7734935879707336
# Epoch: 286, Iteration: 10, Loss: 0.794912576675415
# Epoch 286 completed in 374.46 seconds, mean loss: 0.7993863179133489
# Epoch: 287, Iteration: 0, Loss: 0.7523980140686035
# Epoch: 287, Iteration: 10, Loss: 0.8246334195137024
# Epoch 287 completed in 368.99 seconds, mean loss: 0.8035544477976285
# Epoch: 288, Iteration: 0, Loss: 0.8504287004470825
# Epoch: 288, Iteration: 10, Loss: 0.7780678272247314
# Epoch 288 completed in 362.86 seconds, mean loss: 0.7995089246676519
# Epoch: 289, Iteration: 0, Loss: 0.9029249548912048
# Epoch: 289, Iteration: 10, Loss: 0.8474120497703552
# Epoch 289 completed in 366.26 seconds, mean loss: 0.7949059834847083
# Epoch: 290, Iteration: 0, Loss: 0.9020557403564453
# Epoch: 290, Iteration: 10, Loss: 0.8822558522224426
# Epoch 290 completed in 371.03 seconds, mean loss: 0.7726073356775137
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_290.pt
# Epoch: 291, Iteration: 0, Loss: 0.709051251411438
# Epoch: 291, Iteration: 10, Loss: 0.9604846835136414
# Epoch 291 completed in 355.04 seconds, mean loss: 0.7854773677312411
# Epoch: 292, Iteration: 0, Loss: 0.9014233350753784
# Epoch: 292, Iteration: 10, Loss: 0.7466643452644348
# Epoch 292 completed in 370.02 seconds, mean loss: 0.7746268373269302
# Epoch: 293, Iteration: 0, Loss: 0.8895263671875
# Epoch: 293, Iteration: 10, Loss: 0.7222657799720764
# Epoch 293 completed in 365.30 seconds, mean loss: 0.7974146879636325
# Epoch: 294, Iteration: 0, Loss: 0.7776735424995422
# Epoch: 294, Iteration: 10, Loss: 0.7901931405067444
# Epoch 294 completed in 375.00 seconds, mean loss: 0.7887732936785772
# Epoch: 295, Iteration: 0, Loss: 0.8703528046607971
# Epoch: 295, Iteration: 10, Loss: 0.8828252553939819
# Epoch 295 completed in 378.66 seconds, mean loss: 0.7980033663602976
# Epoch: 296, Iteration: 0, Loss: 0.8861557245254517
# Epoch: 296, Iteration: 10, Loss: 0.7562792897224426
# Epoch 296 completed in 365.86 seconds, mean loss: 0.7738426327705383
# Epoch: 297, Iteration: 0, Loss: 0.7811930179595947
# Epoch: 297, Iteration: 10, Loss: 0.8422093987464905
# Epoch 297 completed in 363.74 seconds, mean loss: 0.7663251436673678
# Epoch: 298, Iteration: 0, Loss: 0.742704451084137
# Epoch: 298, Iteration: 10, Loss: 0.7596712708473206
# Epoch 298 completed in 386.61 seconds, mean loss: 0.7526869590465839
# Epoch: 299, Iteration: 0, Loss: 0.7412453889846802
# Epoch: 299, Iteration: 10, Loss: 0.8031652569770813
# Epoch 299 completed in 366.87 seconds, mean loss: 0.760906655054826
# Epoch: 300, Iteration: 0, Loss: 0.6497134566307068
# Epoch: 300, Iteration: 10, Loss: 0.6309353113174438
# Epoch 300 completed in 361.30 seconds, mean loss: 0.7745753939335163
# Checkpoint saved at ./processed_check_points/checkpoint_epoch_300.pt

# %%
model = Tacotron2(**hparams).to(device)
checkpoint = torch.load(os.path.join('./processed_check_points/','checkpoint_epoch_300.pt'))

load_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['model_state_dict'])

# %%
phoneme_sequence,end_time = read_and_convert_phonemes(tacotron_file_list[0]['phonetic_file'])
print(phoneme_sequence)
length = [len(phoneme_sequence)]
inputs = torch.tensor(phoneme_sequence, dtype=torch.int).unsqueeze(0).to(device)
input_lengths = torch.tensor(length, dtype=torch.int).to(device)
print(inputs.shape)
print(input_lengths)
model.eval()

with torch.no_grad():
    mel_outputs, mel_lengths, alignments = model.infer(inputs, input_lengths)

print("Mel Outputs Postnet:", mel_outputs)
print("Mel Lengths:", mel_lengths)
print("Alignments:", alignments)
print(mel_outputs.shape)
play_audio = play_mel_audio(mel_outputs[0])
play_audio

# %%
raw_audio = load_audio_from_path(tacotron_file_list[0]['audio_file'])
print(raw_audio.shape)
audio_numpy = raw_audio.cpu().numpy()
Audio(audio_numpy, rate=16000)
